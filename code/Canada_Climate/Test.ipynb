# %%
import pandas as pd

# %%
df = pd.read_csv("Homog_monthly_mean_temp (1)/mm6158355.txt",sep='delimiter', header=None)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#                                                    0
# 0  6158355,TORONTO        ,ON, station joined    ...
# 1  6158355,TORONTO        ,ON, station jointe    ...
# 2  Year,     Jan, ,     Feb, ,     Mar, ,     Apr...
# 3  Annee,    Janv, ,     Fev, ,    Mars, ,     Av...
# 4  1840, -9999.9,M, -9999.9,M,     1.2, ,     6.7...

# %%
df_split = df[0].str.split(",", 33, expand = True)

# %%
df_split.drop([0, 3, 4], inplace = True)

# %%
df_split["City"] = df_split[1][1]

# %%
df_split.drop([1], inplace = True)

# %%
df_split.columns = df_split.iloc[0]

# %%
df_split.drop([2], inplace = True)

# %%
list(df_split.columns.values)
# Out:
# ['Year',
#  '     Jan',
#  ' ',
#  '     Feb',
#  ' ',
#  '     Mar',
#  ' ',
#  '     Apr',
#  ' ',
#  '     May',
#  ' ',
#  '     Jun',
#  ' ',
#  '     Jul',
#  ' ',
#  '     Aug',
#  ' ',
#  '     Sep',
#  ' ',
#  '     Oct',
#  ' ',
#  '     Nov',
#  ' ',
#  '     Dec',
#  ' ',
#  '  Annual',
#  ' ',
#  '  Winter',
#  ' ',
#  '  Spring',
#  ' ',
#  '  Summer',
#  ' ',
#  '  Autumn',
#  'TORONTO        ']

# %%
df_split = df_split.rename(columns={ df_split.columns[34]: "City" })

# %%
df_split
# Out:
# 2    Year       Jan          Feb          Mar          Apr          May  \
# 5    1841      -4.5         -5.5         -2.3          4.3         10.9
# 6    1842      -2.8         -2.2          2.7          7.0         10.2
# 7    1843      -2.1         -8.5         -5.8          5.1         10.8
# 8    1844      -6.5         -3.6          0.2          9.3         13.2
# 9    1845      -3.2         -3.5          1.6          5.7         10.3
# 10   1846      -3.8         -7.5         -0.3          6.5         13.2
# 11   1847      -5.3         -5.6         -3.3          3.3         11.5
# 12   1848      -2.7         -2.9         -2.2          4.9         12.1
# 13   1849      -7.3         -7.6          0.4          3.3          8.9
# 14   1850      -1.9         -4.0         -1.7          3.3          9.9
# 15   1851      -4.5         -2.6          0.4          5.0         10.7
# 16   1852      -8.0         -5.2         -3.5          3.1         10.7
# ...

# %%
df_split = df_split.replace("E", "")

# %%
 df_split= df_split.rename(columns=lambda x: x.strip())

# %%
list(df_split.columns.values)
# Out:
# ['Year',
#  'Jan',
#  '',
#  'Feb',
#  '',
#  'Mar',
#  '',
#  'Apr',
#  '',
#  'May',
#  '',
#  'Jun',
#  '',
#  'Jul',
#  '',
#  'Aug',
#  '',
#  'Sep',
#  '',
#  'Oct',
#  '',
#  'Nov',
#  '',
#  'Dec',
#  '',
#  'Annual',
#  '',
#  'Winter',
#  '',
#  'Spring',
#  '',
#  'Summer',
#  '',
#  'Autumn',
#  'City']

# %%
df_split.head()
# Out:
# 2  Year       Jan          Feb          Mar          Apr          May  \
# 5  1841      -4.5         -5.5         -2.3          4.3         10.9
# 6  1842      -2.8         -2.2          2.7          7.0         10.2
# 7  1843      -2.1         -8.5         -5.8          5.1         10.8
# 8  1844      -6.5         -3.6          0.2          9.3         13.2
# 9  1845      -3.2         -3.5          1.6          5.7         10.3
#
# 2       ...           Annual       Winter       Spring       Summer     \
# 5       ...              6.8         -5.0          4.3         19.1
# 6       ...              7.2         -2.3          6.6         17.5
# 7       ...              6.3         -4.8          3.4         17.7
# 8       ...              7.4         -3.6          7.6         18.0
# 9       ...              6.8         -2.9          5.9         18.2
#
# 2     Autumn             City
# 5       7.8,  TORONTO
# 6       7.5,  TORONTO
# 7       7.8,  TORONTO
# 8       7.9,  TORONTO
# ...

# %%
df_split.drop([""], axis=1,inplace = True)

# %%
list(df_split.columns.values)
# Out:
# ['Year',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec',
#  'Annual',
#  'Winter',
#  'Spring',
#  'Summer',
#  'Autumn',
#  'City']

# %%
df_split["Autumn"] = df_split["Autumn"].str.replace("E", "").str.replace(",", "")

# %%
df_split
# Out:
# 2    Year       Jan       Feb       Mar       Apr       May       Jun  \
# 5    1841      -4.5      -5.5      -2.3       4.3      10.9      19.4
# 6    1842      -2.8      -2.2       2.7       7.0      10.2      14.5
# 7    1843      -2.1      -8.5      -5.8       5.1      10.8      14.8
# 8    1844      -6.5      -3.6       0.2       9.3      13.2      16.1
# 9    1845      -3.2      -3.5       1.6       5.7      10.3      15.9
# 10   1846      -3.8      -7.5      -0.3       6.5      13.2      17.4
# 11   1847      -5.3      -5.6      -3.3       3.3      11.5      14.4
# 12   1848      -2.7      -2.9      -2.2       4.9      12.1      16.4
# 13   1849      -7.3      -7.6       0.4       3.3       8.9      16.7
# 14   1850      -1.9      -4.0      -1.7       3.3       9.9      17.4
# 15   1851      -4.5      -2.6       0.4       5.0      10.7      15.0
# 16   1852      -8.0      -5.2      -3.5       3.1      10.7      15.8
# ...
