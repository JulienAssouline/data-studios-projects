# %%
import pandas as pd
# %matplotlib inline
import re

# %%
Friends_finished = pd.read_csv("Friends_finished_4.csv")

# %%
Friends_finished.drop("Unnamed: 0", 1, inplace = True)

# %%
Friends_finished["Scripts"]
# Out:
# False    57856
# True      1785
# Name: Scripts, dtype: int64

# %%
Friends_finished = Friends_finished.loc[Friends_finished['Character'].isin(["monica", "rachel", "ross", "chandler", "joey", "phoebe"])]

# %%
Monica = Friends_finished[Friends_finished["Character"] == "monica"]
Ross = Friends_finished[Friends_finished["Character"] == "ross"]
Joey = Friends_finished[Friends_finished["Character"] == "joey"]
Rachel = Friends_finished[Friends_finished["Character"] == "rachel"]
Chandler = Friends_finished[Friends_finished["Character"] == "chandler"]
Phoebe = Friends_finished[Friends_finished["Character"] == "phoebe"]

# %%
Monica["Scripts"] = Monica["Scripts"].str.lower()

# %%
Monica["Ross"] = Monica["Scripts"].str.contains("ross") 
Monica["Chandler"] = Monica["Scripts"].str.contains("chandler")
Monica["Joey"] = Monica["Scripts"].str.contains("joey")
Monica["Rachel"] = Monica["Scripts"].str.contains("rachel")
Monica["Phoebe"] = Monica["Scripts"].str.contains("phoebe")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
Monica_mentions = Monica["Ross"].value_counts().reset_index()

# %%
Monica_mentions["Chandler"] = Monica["Chandler"].value_counts()
Monica_mentions["Rachel"] = Monica["Rachel"].value_counts()
Monica_mentions["Joey"] = Monica["Joey"].value_counts()
Monica_mentions["Ross"] = Monica["Ross"].value_counts()
Monica_mentions["Phoebe"] = Monica["Phoebe"].value_counts()

# %%
Monica_mentions = Monica_mentions[Monica_mentions["index"] != False]

# %%
Monica_mentions
# Out:
#    index  Ross  Chandler  Rachel  Joey  Phoebe
# 1   True   267       454     294   291     341

# %%
Ross["Scripts"] = Ross["Scripts"].str.lower()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Ross
# Out:
#       Character  Episode Number  \
# 17         ross             1.0
# 20         ross             1.0
# 25         ross             1.0
# 27         ross             1.0
# 29         ross             1.0
# 31         ross             1.0
# 33         ross             1.0
# 35         ross             1.0
# 37         ross             1.0
# 40         ross             1.0
# 47         ross             1.0
# 54         ross             1.0
# 61         ross             1.0
# 77         ross             1.0
# 79         ross             1.0
# 85         ross             1.0
# 87         ross             1.0
# 93         ross             1.0
# 100        ross             1.0
# 102        ross             1.0
# 105        ross             1.0
# 109        ross             1.0
# 118        ross             1.0
# 122        ross             1.0
# 136        ross             1.0
# 139        ross             1.0
# 141        ross             1.0
# 143        ross             1.0
# 161        ross             1.0
# 165        ross             1.0
# ...         ...             ...
# 59295      ross             NaN
# 59297      ross             NaN
# 59299      ross             NaN
# 59301      ross             NaN
# 59303      ross             NaN
# 59305      ross             NaN
# 59307      ross             NaN
# 59309      ross             NaN
# 59311      ross             NaN
# 59317      ross             NaN
# 59319      ross             NaN
# 59322      ross             NaN
# 59326      ross             NaN
# 59328      ross             NaN
# 59330      ross             NaN
# 59377      ross             NaN
# 59413      ross             NaN
# 59415      ross             NaN
# 59417      ross             NaN
# 59513      ross             NaN
# 59586      ross             NaN
# 59588      ross             NaN
# 59616      ross             NaN
# 59620      ross             NaN
# 59623      ross             NaN
# 59628      ross             NaN
# 59630      ross             NaN
# 59637      ross             NaN
# 59639      ross             NaN
# 59641      ross             NaN
#
#                                                  Scripts  Season  negative  \
# 17                                       (mortified) hi.       1  0.000000
# 20     i just feel like someone reached down my throa...       1  0.166667
# 25                                               thanks.       1  0.000000
# 27     no, no don't! stop cleansing my aura! no, just...       1  0.166667
# 29     i'll be fine, alright? really, everyone. i hop...       1  0.000000
# 31            no i don't, to hell with her, she left me!       1  0.333333
# 33     no!! okay?! why does everyone keep fixating on...       1  0.000000
# 35     i told mom and dad last night, they seemed to ...       1  0.000000
# 37                                                sorry.       1  0.000000
# 40     i don't want to be single, okay? i just... i j...       1  0.000000
# 47                                                   hi.       1  0.000000
# 54     (in a deep voice) i'll have whatever christine...       1  0.000000
# 61                  you can see where he'd have trouble.       1  0.000000
# 77                              paul the wine guy, paul?       1  0.000000
# 79                             he finally asked you out?       1  0.000000
# 85                      (choked voice) that'd be good...       1  0.000000
# 87     (normal voice) no, go on! it's paul the wine guy!       1  0.000000
# 93                                          a wandering?       1  0.000000
# 100    so rachel, what're you, uh... what're you up t...       1  0.000000
# 102    right, you're not even getting your honeymoon,...       1  0.000000
# 105                                          okay, sure.       1  0.000000
# 109    (squatting and reading the instructions) i'm s...       1  0.153846
# 118    (clutching a beer can and sniffing) this was c...       1  0.000000
# 122                                            you guys.       1  0.000000
# 136         i'm divorced!â i'm only 26 and i'm divorced!       1  0.000000
# 139                           that only took me an hour.       1  0.000000
# 141    you know what the scariest part is? what if th...       1  0.200000
# 143        i honestly don't know if i'm hungry or horny.       1  0.333333
# 161    (scornful) grab a spoon. do you know how long ...       1  0.250000
# 165    y'know, here's the thing. even if i could get ...       1  0.000000
# ...                                                  ...     ...       ...
# 59295     oh, here, i, i'll get it for ya. whad'ya want?       2  0.000000
# 59297   scotch. alright, i'll be back in 10 seconds w...       2  0.400000
# 59299                                              cool.       2  0.000000
# 59301                                            i know.       2  0.000000
# 59303   hi. uh, i have been in the bathroom. stay cle...       2  0.000000
# 59305   oh, mine too. isn't that neat, scotch neat. w...       2  0.333333
# 59307                                            no. no.       2  0.000000
# 59309   no, um, see 'cause that, that is, that is the...       2  0.428571
# 59311   all righty roo. closes the door what a great ...       2  0.000000
# 59317                                              mine.       2  0.000000
# 59319   um-hmm. puts them on i have a condition, appa...       2  0.000000
# 59322                            neil sedaka wears them.       2  0.000000
# 59326   ohh, big smoker. packs the cigarettes and fli...       2  0.250000
# 59328   yes. pulls them off and hands them to mr. gre...       2  0.000000
# 59330   pulls the cigarette off his upper lip and han...       2  0.250000
# 59377   i'm getting ready for the water skiing. mr. g...       2  0.000000
# 59413                                       enters hiii.       2  0.000000
# 59415   well, i just spoke to carol. ben's got the ch...       2  0.250000
# 59417   yeah, so if you haven't already had it, chanc...       2  0.000000
# 59513   you know, i might have expected this of you p...       2  0.000000
# 59586                                   ok, dinner's on.       2  0.000000
# 59588                         alright you kids, bye now.       2  0.000000
# 59616   so do you have like any nuclear weapons on bo...       2  0.000000
# 59620      wow, it, it's neat learning about submarines.       2  0.000000
# 59623                                          bye ryan.       2  0.000000
# 59628                               you like that do ya?       2  0.000000
# 59630                    i'll make some calls. runs off.       2  0.500000
# 59637                      is this what you had in mind?       2  0.000000
# 59639                         i'm shipping out tomorrow.       2  0.000000
# 59641   alright you know, why don't i just meet you u...       2  0.142857
#
#        positive                                              title  Line
# 17     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 20     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 25     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 27     0.666667  The One Where Monica Gets a New Roommate (The ...     1
# 29     1.000000  The One Where Monica Gets a New Roommate (The ...     1
# 31     0.333333  The One Where Monica Gets a New Roommate (The ...     1
# 33     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 35     0.333333  The One Where Monica Gets a New Roommate (The ...     1
# 37     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 40     0.333333  The One Where Monica Gets a New Roommate (The ...     1
# 47     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 54     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 61     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 77     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 79     1.000000  The One Where Monica Gets a New Roommate (The ...     1
# 85     0.500000  The One Where Monica Gets a New Roommate (The ...     1
# 87     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 93     0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 100    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 102    0.333333  The One Where Monica Gets a New Roommate (The ...     1
# 105    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 109    0.076923  The One Where Monica Gets a New Roommate (The ...     1
# 118    1.000000  The One Where Monica Gets a New Roommate (The ...     1
# 122    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 136    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 139    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 141    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# 143    0.333333  The One Where Monica Gets a New Roommate (The ...     1
# 161    0.250000  The One Where Monica Gets a New Roommate (The ...     1
# 165    0.000000  The One Where Monica Gets a New Roommate (The ...     1
# ...         ...                                                ...   ...
# 59295  0.000000                       The One With the Two Parties     1
# 59297  0.000000                       The One With the Two Parties     1
# 59299  1.000000                       The One With the Two Parties     1
# 59301  0.000000                       The One With the Two Parties     1
# 59303  0.000000                       The One With the Two Parties     1
# 59305  0.000000                       The One With the Two Parties     1
# 59307  0.000000                       The One With the Two Parties     1
# 59309  0.142857                       The One With the Two Parties     1
# 59311  0.000000                       The One With the Two Parties     1
# 59317  0.000000                       The One With the Two Parties     1
# 59319  0.000000                       The One With the Two Parties     1
# 59322  0.000000                       The One With the Two Parties     1
# 59326  0.062500                       The One With the Two Parties     1
# 59328  0.000000                       The One With the Two Parties     1
# 59330  0.000000                       The One With the Two Parties     1
# 59377  0.000000                       The One With the Two Parties     1
# 59413  0.000000                       The One With the Chicken Pox     1
# 59415  0.250000                       The One With the Chicken Pox     1
# 59417  1.000000                       The One With the Chicken Pox     1
# 59513  0.000000                       The One With the Chicken Pox     1
# 59586  1.000000                       The One With the Chicken Pox     1
# 59588  0.000000                       The One With the Chicken Pox     1
# 59616  0.000000                       The One With the Chicken Pox     1
# 59620  1.000000                       The One With the Chicken Pox     1
# 59623  0.000000                       The One With the Chicken Pox     1
# 59628  0.000000                       The One With the Chicken Pox     1
# 59630  0.000000                       The One With the Chicken Pox     1
# 59637  0.000000                       The One With the Chicken Pox     1
# 59639  0.000000                       The One With the Chicken Pox     1
# 59641  0.142857                       The One With the Chicken Pox     1
#
# [8801 rows x 8 columns]

# %%
Ross["Monica"] = Ross["Scripts"].str.contains("monica") 
Ross["Chandler"] = Ross["Scripts"].str.contains("chandler")
Ross["Joey"] = Ross["Scripts"].str.contains("joey")
Ross["Rachel"] = Ross["Scripts"].str.contains("rachel")
Ross["Phoebe"] = Ross["Scripts"].str.contains("phoebe")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
Ross_mentions = Ross["Chandler"].value_counts().reset_index()

# %%
Ross_mentions["Rachel"] = Ross["Rachel"].value_counts()
Ross_mentions["Joey"] = Ross["Joey"].value_counts()
Ross_mentions["Monica"] = Ross["Monica"].value_counts()
Ross_mentions["Phoebe"] = Ross["Phoebe"].value_counts()

# %%
Ross_mentions = Ross_mentions[Ross_mentions["index"] != False]

# %%
Ross_mentions
# Out:
#    index  Chandler  Rachel  Joey  Monica  Phoebe
# 1   True       251     398   285     197     161

# %%
Joey["Scripts"] = Joey["Scripts"].str.lower()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Joey["Monica"] = Joey["Scripts"].str.contains("monica") 
Joey["Chandler"] = Joey["Scripts"].str.contains("chandler")
Joey["Ross"] = Joey["Scripts"].str.contains("ross")
Joey["Rachel"] = Joey["Scripts"].str.contains("rachel")
Joey["Phoebe"] = Joey["Scripts"].str.contains("phoebe")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
Joey_mentions = Joey["Chandler"].value_counts().reset_index()

# %%
Joey_mentions
# Out:
#    index  Chandler
# 0  False      7479
# 1   True       403

# %%
Joey_mentions["Rachel"] = Joey["Rachel"].value_counts()
Joey_mentions["Ross"] = Joey["Ross"].value_counts()
Joey_mentions["Monica"] = Joey["Monica"].value_counts()
Joey_mentions["Phoebe"] = Joey["Phoebe"].value_counts()

# %%
Joey_mentions = Joey_mentions[Joey_mentions["index"] != False]

# %%
Joey_mentions
# Out:
#    index  Chandler  Rachel  Ross  Monica  Phoebe
# 1   True       403     198   426     200     141

# %%
Rachel["Scripts"] = Rachel["Scripts"].str.lower()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
Rachel["Monica"] = Rachel["Scripts"].str.contains("monica") 
Rachel["Chandler"] = Rachel["Scripts"].str.contains("chandler")
Rachel["Ross"] = Rachel["Scripts"].str.contains("ross")
Rachel["Joey"] = Rachel["Scripts"].str.contains("joey")
Rachel["Phoebe"] = Rachel["Scripts"].str.contains("phoebe")
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
Rachel_mentions = Rachel["Monica"].value_counts().reset_index()

Rachel_mentions
# Out:
#    index  Monica
# 0  False    8559
# 1   True     326

# %%
Rachel_mentions["Rachel"] = Rachel["Joey"].value_counts()
Rachel_mentions["Ross"] = Rachel["Ross"].value_counts()
Rachel_mentions["Monica"] = Rachel["Monica"].value_counts()
Rachel_mentions["Phoebe"] = Rachel["Phoebe"].value_counts()
