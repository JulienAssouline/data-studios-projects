# %%
import pandas as pd
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams["pdf.fonttype"] = 42

# %%
GoT_deaths = pd.read_csv("GoT deaths.csv")
GoT_deaths.head()
# Out:
#    Unnamed: 0  Episode  number                Deaths
# 0           0        1       0      Ser Waymar Royce
# 1           1        2       0      Catspaw assassin
# 2           2        3       0                  None
# 3           3        4       0  Ser Hugh of the Vale
# 4           4        5       0              Kurleket

# %%
del GoT_deaths["Unnamed: 0"]

# %%
del GoT_deaths["number"]

# %%
GoT_deaths.columns = ["Episodes_deaths", "Deaths"]

# %%
GoT_deaths.head()
# Out:
#    Episodes_deaths                Deaths
# 0                1      Ser Waymar Royce
# 1                2      Catspaw assassin
# 2                3                  None
# 3                4  Ser Hugh of the Vale
# 4                5              Kurleket

# %%
First_appearance = pd.read_csv("first appearance GoT.csv")
First_appearance.head()
# Out:
#    Unnamed: 0  Episodes  number     Characters
# 0           0         1       0           Will
# 1           1         2       0         Doreah
# 2           2         3       0  Royal Steward
# 3           3         4       0  Samwell Tarly
# 4           4         5       0   Loras Tyrell

# %%
del First_appearance["Unnamed: 0"]
del First_appearance["number"]

# %%
First_appearance.columns = ["Episodes_First", "Characters"]

# %%
First_appearance.head()
# Out:
#    Episodes_First     Characters
# 0               1           Will
# 1               2         Doreah
# 2               3  Royal Steward
# 3               4  Samwell Tarly
# 4               5   Loras Tyrell

# %%
pd.set_option("display.max_rows",600)

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.replace("^King", "").str.replace("^Prince", "").str.replace("Princess", "").str.replace("Queen", "").str.replace("Ser", "").str.replace("Lord", "")
First_appearance.head()
# Out:
#    Episodes_First     Characters
# 0               1           Will
# 1               2         Doreah
# 2               3  Royal Steward
# 3               4  Samwell Tarly
# 4               5   Loras Tyrell

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.replace("^ss ", "")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.strip()

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("King", "").str.replace("Prince", "").str.replace("Princess", "").str.replace("Queen", "").str.replace("Ser", "").str.replace("Lord", "").str.replace("Commander","").str.replace("Later Resurrected","").str.replace("(","").str.replace(")","").str.replace(" Hand of The King", "").str.replace(" I "," ").str.replace("-Beyond-the-Wall ","").str.replace(" Warden of The North &","").str.replace("ss", "")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.strip()

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.strip()

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("King","")

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.replace("Commander","").str.replace("King","")

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.replace("Ramsay Snow","Ramsay Bolton")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace(" & Protector of The Realm", "")

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.replace("Lady Olenna Tyrell", "Olenna Tyrell")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Jon Umber", "Smalljon Umber")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace(" Warden of The South", "")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Talisa Stark", "Talisa Maegyr")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Lady Walda Bolton", "Walda Bolton")

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Brynden Tully", 'Brynden "The Blackfish" Tully')

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Shaggydog Confirmed Fate", 'Shaggydog')

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.strip()

# %%
First_appearance["Characters"] = First_appearance["Characters"].str.strip()

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Eddard Stark Hand of The", 'Eddard Stark')

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Kevan Lannister Hand of The", 'Kevan Lannister')

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("Tywin Lannister Hand of The", 'Tywin Lannister')

# %%
GoT_deaths["Deaths"] = GoT_deaths["Deaths"].str.replace("^Lady ", '')

# %%
GoT_deaths.sort_values(by ="Episodes_deaths")
# Out:
#      Episodes_deaths                                           Deaths
# 0                  1                                     Waymar Royce
# 117                1  Jon Arryn Hand of the king & Warden of the East
# 167                1                                             Will
# 206                1                      At least 1 unnamed Dothraki
# 63                 1                                            Gared
# 1                  2                                     Catspaw aain
# 118                2                                             Lady
# 64                 2                                            Mycah
# 2                  3                                             None
# 3                  4                                 Hugh of the Vale
# 207                5                                        Jory Cael
# 238                5             At least 6 unnamed mountain clansmen
# ...

# %%
First_appearance
# Out:
#      Episodes_First                                 Characters
# 0                 1                                       Will
# 1                 2                                     Doreah
# 2                 3                              Royal Steward
# 3                 4                              Samwell Tarly
# 4                 5                               Loras Tyrell
# 5                 6                                       Osha
# 6                 7                            Tywin Lannister
# 7                 8                                Vayon Poole
# 8                 9                                Walder Frey
# 9                10                           Rickard Karstark
# 10               11                               Lothor Brune
# 11               12  Jaqen H'ghar (as played by Tom Wlaschiha)
# 12               13                           Brienne of Tarth
# 13               14                                    Rennick
# ...

# %%
First_Death_merged = First_appearance.merge(GoT_deaths, left_on = "Characters", right_on = "Deaths", how="left")

# %%
First_Death_merged
# Out:
#      Episodes_First                                 Characters  \
# 0                 1                                       Will
# 1                 2                                     Doreah
# 2                 3                              Royal Steward
# 3                 4                              Samwell Tarly
# 4                 5                               Loras Tyrell
# 5                 6                                       Osha
# 6                 7                            Tywin Lannister
# 7                 8                                Vayon Poole
# 8                 9                                Walder Frey
# 9                10                           Rickard Karstark
# 10               11                               Lothor Brune
# 11               12  Jaqen H'ghar (as played by Tom Wlaschiha)
# 12               13                           Brienne of Tarth
# 13               14                                    Rennick
# ...

# %%
GoT_Final = pd.read_csv("GoT - Sheet1 (1).csv")

# %%
GoT_Final = GoT_Final[GoT_Final.Deaths != 'Deaths']

# %%
GoT_Final["Deaths"].value_counts()
# Out:
# Unknown fate    231
# Dead            203
# Alive            50
# Last seen        18
# Name: Deaths, dtype: int64

# %%
GoT_Final.loc[18, "Episodes_deaths"] = "64"

# %%
GoT_Final.sort_values(by="Characters",inplace=True)

# %%
GoT_Final.to_csv("GoT_Final_3.csv")

# %%
GoT_Final.sort_values(by = "Deaths", inplace = True)

# %%
GoT_Final["Episodes_First"] = GoT_Final["Episodes_First"].astype(int)

# %%
GoT_Final["Episodes_deaths"] = GoT_Final["Episodes_deaths"].astype(int)

# %%
GoT_Final["Difference"] = GoT_Final["Episodes_First"] - GoT_Final["Episodes_deaths"]

# %%
GoT_Final.loc[350, "Deaths"] = "Dead"

# %%
GoT_Final.loc[391, "Episodes_deaths"] = 31

# %%
GoT_Final.sort_values(by = "Characters", inplace = True)

# %%
GoT_Final.sort_values(by = "Episodes_First", inplace = True)

# %%
GoT_Final
# Out:
#      Episodes_First                          Characters  Episodes_deaths  \
# 259               1                               Haggo                1
# 482               1                   Viserys Targaryen                6
# 255               1                  Preston Greenfield                1
# 229               1                              Summer               55
# 82                1                        Eddard Stark                9
# 128               1                        Benjen Stark               60
# 5                 1                       Theon Greyjoy               64
# 242               1                    Tommen Baratheon               60
# 254               1                               Tommy                1
# 257               1                    Pentoshi servant                1
# 495               1                                Will                1
# 248               1                       Wildling girl                1
# ...

# %%
GoT_Final.to_csv("GoT_Final_3.csv")

# %%
GoT_Final_known_fate = GoT_Final[GoT_Final.Deaths != 'Unknown fate']

# %%
GoT_Final_known_fate.head()
# Out:
#      Episodes_First       Characters  Episodes_deaths     Deaths  Difference
# 0                38    Adrack Humble               38       Dead           0
# 144              52    Aeron Greyjoy               55  Last seen          -3
# 1                51             Akho               54       Dead          -3
# 52                3   Alliser Thorne               53       Dead         -50
# 53               11  Alton Lannister               17       Dead          -6

# %%
GoT_Final_known_fate.sort_values(by = "Episodes_First", inplace = True)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
GoT_Final_known_fate.to_csv("GoT_Final_known_fate.csv")

# %%
GoT_Final_known_fate
# Out:
#      Episodes_First                     Characters  Episodes_deaths  \
# 216               1                  Septa Mordane                8
# 211               1               Robert Baratheon                7
# 12                1             Daenerys Targaryen               64
# 210               1                     Robb Stark               29
# 486               1                   Waymar Royce                1
# 82                1                   Eddard Stark                9
# 219               1                      Shaggydog               53
# 207               1                   Rickon Stark               59
# 86                1                          Gared                1
# 7                 1                          Ghost               64
# 482               1              Viserys Targaryen                6
# 93                1                      Grey Wind               29
# 99                1                          Hodor               55
# ...

# %%
GoT_Final_known_fate_1 = pd.read_csv("GoT_Final_known_fate.csv")

# %%
GoT_Final_known_fate_1 = GoT_Final_known_fate_1[GoT_Final_known_fate_1["Unnamed: 0"] != 133]

# %%
GoT_Final_known_fate_1 = GoT_Final_known_fate_1[GoT_Final_known_fate_1["Difference"] != 6]

# %%
GoT_Final_known_fate_1 = GoT_Final_known_fate_1[GoT_Final_known_fate_1["Difference"] != 20]

# %%
GoT_Final_known_fate_1[GoT_Final_known_fate_1["Characters"] == "Jon Snow"]
# Out:
#     Unnamed: 0  Episodes_First Characters  Episodes_deaths Deaths  Difference
# 15         110               1   Jon Snow               64   Dead         -49

# %%
GoT_Final_known_fate_1.loc[15,'Episodes_deaths'] = 64

# %%
GoT_Final_known_fate_1.sort_values(by = "Difference")
# Out:
#      Unnamed: 0  Episodes_First             Characters  Episodes_deaths  \
# 30            6               1                Nymeria               64
# 2            12               1     Daenerys Targaryen               64
# 32            3               1            Sansa Stark               64
# 22            5               1          Theon Greyjoy               64
# 35            4               1             Arya Stark               64
# 36            2               1             Bran Stark               64
# 18           11               1       Tyrion Lannister               64
# 9             7               1                  Ghost               64
# 37           10               1         Sandor Clegane               64
# 16           13               1          Jorah Mormont               64
# 28            9               1       Cersei Lannister               64
# 13            8               1        Jaime Lannister               64
# ...

# %%
GoT_Final_known_fate_1[GoT_Final_known_fate_1["Episodes_deaths"] == 58]
# Out:
#      Unnamed: 0  Episodes_First                     Characters  \
# 113         134              12                  Jaqen H'ghar
# 162         137              23                   Edmure Tully
# 166          70              23  Brynden "The Blackfish" Tully
# 186         174              31                         Morgan
# 222         239              43                       The Waif
# 264         175              57                         Morgan
# 265         225              58                          Steve
# 266         208              58                        Riddell
#
#      Episodes_deaths     Deaths  Difference
# 113               58  Last seen         -46
# 162               58  Last seen         -35
# 166               58       Dead         -35
# 186               58       Dead         -27
# 222               58       Dead         -15
# 264               58       Dead          -1
# 265               58       Dead           0
# ...

# %%
GoT_Final_known_fate_Deaths = GoT_Final_known_fate_1[GoT_Final_known_fate_1["Deaths"] == "Dead"]

# %%
GoT_Final_known_fate_Deaths.head()
# Out:
#    Unnamed: 0  Episodes_First        Characters  Episodes_deaths Deaths  \
# 0         216               1     Septa Mordane                8   Dead
# 1         211               1  Robert Baratheon                7   Dead
# 3         210               1        Robb Stark               29   Dead
# 4         486               1      Waymar Royce                1   Dead
# 5          82               1      Eddard Stark                9   Dead
#
#    Difference
# 0          -7
# 1          -6
# 3         -28
# 4           0
# 5          -8

# %%
GoT_Final_known_fate_Deaths.sort_values(by = "Difference")
# Out:
#      Unnamed: 0  Episodes_First                     Characters  \
# 20          242               1               Tommen Baratheon
# 7           207               1                   Rickon Stark
# 56           89               3          Grand Maester Pycelle
# 46          124               3               Lancel Lannister
# 66          150               5                   Loras Tyrell
# 12           99               1                          Hodor
# 27          229               1                         Summer
# 6           219               1                      Shaggydog
# 82          114               8                Kevan Lannister
# 91          484               9                    Walder Frey
# 47           52               3                 Alliser Thorne
# 26          179               1             Myrcella Baratheon
# 15          110               1                       Jon Snow
# 75          189               6                           Osha
# ...

# %%
GoT_deaths_by_episode = GoT_Final_known_fate_Deaths["Episodes_deaths"].value_counts().reset_index()

# %%
GoT_deaths_by_episode = pd.DataFrame(GoT_deaths_by_episode)

# %%
GoT_deaths_by_episode = GoT_deaths_by_episode[GoT_deaths_by_episode["index"] != 64]

# %%
GoT_deaths_by_episode.sort_values(by="Episodes_deaths")
# Out:
#     index  Episodes_deaths
# 54     57                1
# 45     21                1
# 46     22                1
# 47     23                1
# 48     26                1
# 53      4                1
# 50     45                1
# 51     46                1
# 52     47                1
# 49     12                1
# 34     11                2
# 35     13                2
# 36      9                2
# 38      2                2
# 37      7                2
# 41     41                2
# 42     43                2
# 43     49                2
# 44     31                2
# 39     63                2
# 40     62                2
# 28     10                3
# 33     18                3
# 32     44                3
# 31     37                3
# 30     35                3
# 29     32                3
# 27      1                3
# 26     19                3
# 25     51                4
# 24      5                4
# 23     48                4
# 22     16                4
# ...

# %%
GoT_deaths_by_episode.to_csv("GoT_deaths_by_episode_2.csv")

# %%
GoT_Episodes_First = GoT_Final_known_fate_1["Episodes_First"].value_counts().reset_index()

# %%
GoT_Episodes_First = pd.DataFrame(GoT_Episodes_First)

# %%
GoT_Episodes_First.to_csv("GoT_Episodes_First.csv")

# %%
GoT_Episodes_First
# Out:
#     index  Episodes_First
# 0       1              38
# 1       3              14
# 2      14              11
# 3      11              11
# 4      22               9
# 5       4               8
# 6      15               8
# 7       5               8
# 8       8               8
# 9      21               7
# 10     44               6
# 11     23               6
# 12      2               6
# 13     38               6
# 14     54               6
# 15     12               6
# 16     33               6
# 17     10               6
# 18     48               6
# 19     31               5
# 20     51               5
# 21     52               5
# 22     25               5
# 23     32               4
# 24     28               4
# 25     57               4
# 26     13               4
# 27     39               4
# 28      7               4
# 29      6               4
# 30     40               4
# 31     17               3
# 32     61               3
# 33     42               3
# ...

# %%
GoT_Final_known_fate_1.head()
# Out:
#    Unnamed: 0  Episodes_First          Characters  Episodes_deaths Deaths  \
# 0         216               1       Septa Mordane                8   Dead
# 1         211               1    Robert Baratheon                7   Dead
# 2          12               1  Daenerys Targaryen               64  Alive
# 3         210               1          Robb Stark               29   Dead
# 4         486               1        Waymar Royce                1   Dead
#
#    Difference
# 0          -7
# 1          -6
# 2         -63
# 3         -28
# 4           0

# %%
GoT_Final_known_fate_1 = GoT_Final_known_fate_1.sort_values(by = ["Deaths", "Episodes_deaths"])

# %%
GoT_Final_known_fate_1.to_csv("GoT_Final_known_fate.csv")

# %%
GoT_Final_known_fate_1.to_csv("GoT_Final_known_fate_1.csv")

# %%
GoT_Final_known_fate_Deaths.to_csv("GoT_Deaths.csv")

# %%
GoT_Final_known_fate_Deaths = GoT_Final_known_fate_Deaths.sort_values(by ="Episodes_deaths")

# %%
GoT_Final_known_fate_Deaths.to_csv("GoT_Deaths_sorted.csv")

# %%
GoT_Final_known_fate_1["Deaths"].value_counts()
# Out:
# Dead         204
# Alive         50
# Last seen     17
# Name: Deaths, dtype: int64
