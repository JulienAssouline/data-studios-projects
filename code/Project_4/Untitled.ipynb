# %%
import pandas as pd
# %matplotlib inline
xls = pd.ExcelFile("SubwayDelay2014-2016.xlsx")
subway_delays = xls.parse('Incidents')

# %%
subway_delays.head()
# Out:
#         Date   Time        Day                Station   Code  Min Delay  \
# 0 2014-01-01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1 2014-01-01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 2 2014-01-01  02:40  Wednesday       SHEPPARD STATION  MUNCA          0
# 3 2014-01-01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4 2014-01-01  03:20  Wednesday          BLOOR STATION  MUSAN          5
#
#    Min Gap Bound Line  Vehicle
# 0       60     W   BD     5111
# 1        7     W   BD     5001
# 2        0   NaN   YU        0
# 3        8     W   BD     5116
# 4       10     S   YU     5386

# %%
subway_delays["Year"] = subway_delays["Date"].astype(str).str.split("-", 3, expand = True)[0]

# %%
subway_delays.head()
# Out:
#         Date   Time        Day                Station   Code  Min Delay  \
# 0 2014-01-01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1 2014-01-01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 2 2014-01-01  02:40  Wednesday       SHEPPARD STATION  MUNCA          0
# 3 2014-01-01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4 2014-01-01  03:20  Wednesday          BLOOR STATION  MUSAN          5
#
#    Min Gap Bound Line  Vehicle  Year
# 0       60     W   BD     5111  2014
# 1        7     W   BD     5001  2014
# 2        0   NaN   YU        0  2014
# 3        8     W   BD     5116  2014
# 4       10     S   YU     5386  2014

# %%
subway_delays["Year"].value_counts()
# Out:
# 2015    21474
# 2016    21162
# 2014    20424
# Name: Year, dtype: int64

# %%
subway_delays.groupby("Line")["Year"].value_counts()
# Out:
# Line                 Year
# 104 FAYWOOD          2015        1
# 116 MORNINGSIDE      2016        1
# 126 CHRISTIE         2015        1
# 25 DON MILLS         2015        1
# 29 DUFFERIN          2016        1
# 31 GREENWOOD         2014        1
# 341 KEELE            2016        1
# 36 FINCH WEST        2015        1
# 37 ISLINGTON         2015        1
# 45 KIPLING           2014        1
# 500                  2015        1
# 504                  2015        1
# 504 KING             2016        1
# 510 SPADINA          2016        1
# 555                  2015        1
# 60                   2014        1
# 60 STEELES WEST      2015        1
# 66                   2016        1
# 73 ROYAL YORK        2016        1
# 9 BELLAMY            2014        1
# 95 YORK MILLS        2015        1
# BD                   2015    10977
#                      2016    10627
#                      2014     8859
# BD LINE              2014        1
#                      2016        1
# ...
