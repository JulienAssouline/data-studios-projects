# %%
import tweepy
from time import sleep
from DataManager import DataManager
import pandas as pd

# %%
from requests.exceptions import Timeout, ConnectionError
from requests.packages.urllib3.exceptions import ReadTimeoutError

# %% [markdown]
# # Here you set your keys, get your own from the twitter page, you have to register your phone

# %%
pd.options.display.max_colwidth = 1600

# %%
consumer_key = 'DejAUSB73mmaBDJxPxn5xNSgX'
consumer_secret = 'vq3jwehBHzPv0fc4rd5AyVkpUOxRRPkTFgh6Qs8fzGwIx1pkrl'
access_token = '808325232687775744-HOnh3eBKmbn8ZVcw6T1rZgcNSN8heg1'
access_token_secret = 'HJ1dx748HKhh7J9KIMQsAHhdsKi4yzTrLGHBcTmmNWVx0'

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
auth.secure = True
api = tweepy.API(auth)
myBot = api.get_user(screen_name = '@Throawaybro')
places = api.geo_search(query="UK", granularity="country")
place_id = places[0].id



#api.create_list(name = "Sorry for adding you", mode="public", description = 'I had to add you sorry :( ')
#print(str(api.get_user(screen_name = '@IoannisAntypas')))
# myList = api.get_list(owner=myBot, slug='sorry-for-adding-you')

# %% [markdown]
# # This is optional if you want to store them in text files or create lists or retweet people

# %%
#Create a list and add people in it, for monitoring?
myList = api.get_list("@"+ myBot.screen_name, slug='sorry-for-adding-you')
print("Running bot: @" + myBot.screen_name + "\n Using list: " + myList.name + " \n Members count: " + str(myList.member_count) + " Subs count: " + str(myList.subscriber_count))
# Out:
# Running bot: @Throawaybro
#  Using list: Sorry for adding you
#  Members count: 31 Subs count: 0

# %%
myData = DataManager("Datafiletweet.txt")
listData = DataManager("listData.txt")

# %%
#text , user.name, description, followers_count, friends_count, created_at, favourites_count, time_zone, retweet_count

# %% [markdown]
# # This here accesses the API and downloads the jsons very fast
#
#
# It then pauses before reaching the limit. It automatically stores the following data in a list. Pay attention to the "q=" part and the "lang" and the ."items"

# %%
our_list = []


count_tweet = 0
for tweet in tweepy.Cursor(api.search,q='#metoo',lang='en',include_entities=True).items(600000):
    if not tweet.retweeted:
        count_tweet += 1
        try:
            dictionary = {}


            print("\n\nFound tweet by: @" + tweet.user.screen_name)
            print(count_tweet)
            if count_tweet == 2500:
                print("Too much gonna sleep!")
                sleep(900)
                count_tweet = 0
                print("Okay reset!")
                continue





            if tweet.user.id == myBot.id or (myData.is_stored_b(str(tweet.id))):
                continue
            screen_name = str(tweet.user.screen_name)
            if screen_name:
                dictionary['screen_name'] = screen_name

            tweet_creation_date = str(tweet.created_at)
            if tweet_creation_date:
                dictionary['tweet_creation_date'] = tweet_creation_date


            user_description = str(tweet.user.description)
            if user_description:
                dictionary['user_description'] = user_description
            tweet_text = str(tweet.text)
            if tweet_text:
                dictionary['tweet_text'] = tweet_text
            followers_count = str(tweet.user.followers_count)
            if followers_count:
                dictionary['followers_count'] = followers_count

            account_creation_date = str(tweet.user.created_at)
            if account_creation_date:
                dictionary['account_creation_date'] = account_creation_date

            time_zone = str(tweet.user.time_zone)
            if time_zone:
                dictionary['time_zone'] = time_zone

            friends_count = str(tweet.user.friends_count)      
            if friends_count:
                dictionary['friends_count'] = friends_count

            coordinates = str(tweet.coordinates)
            if coordinates:
                dictionary['coordinates'] = coordinates
            user_id = str(tweet.user.id)
            if user_id:
                dictionary['user_id'] = user_id
            location = str(tweet.user.location)
            if location:
                dictionary['location'] = location
            total_retweets = str(tweet.retweet_count)
            if total_retweets:
                dictionary['total_retweets'] = total_retweets

            our_list.append(dictionary)
        except (Timeout, ssl.SSLError, ReadTimeoutError, ConnectionError) as exc:
            continue


        except tweepy.TweepError as e:
            print(e.reason)
            if "429" in e.reason:
                print("Found a 429!!!")
                sleep(1000)
            else:
                sleep(10)
            continue
            if "403" in e.reason:
                if count403 > 15:
                    print("There are too many 403 errors. Pausing for 30 mins")
                    sleep(1800)
                else:
                    count403 += 1
                    print("Another 403 error. Total: " + str(count403))
                    sleep(1)
        
        except StopIteration:
            break
# Out:
# Found tweet by: @Burchey_Boy
# 1
#
#
# Found tweet by: @StarraAngelle
# 2
#
#
# Found tweet by: @zicknimmerman
# 3
#
#
# Found tweet by: @Blazzdddup
# 4
#
#
# Found tweet by: @ceeyahnow
# 5
#
#
# Found tweet by: @challrn181
# 6
#
#
# Found tweet by: @couricshargitay
# 7
#
#
# Found tweet by: @Confessionfilm
# 8
#
#
# Found tweet by: @BiteMeTrump2016
# 9
#
#
# Found tweet by: @Pamela994118
# 10
#
#
# Found tweet by: @SealamReddy
# 11
#
#
# Found tweet by: @LFCfootieUSA
# 12
#
#
# Found tweet by: @ITBeHa
# 13
#
#
# Found tweet by: @alltidashley
# 14
#
#
# Found tweet by: @nisajaie
# 15
#
#
# Found tweet by: @GeorgeBarilla
# 16
#
#
# Found tweet by: @shelleyzross
# 17
#
#
# Found tweet by: @JanetNestor
# 18
#
#
# Found tweet by: @MGieselmann
# 19
#
#
# Found tweet by: @MGieselmann
# 20
#
#
# Found tweet by: @MGieselmann
# 21
#
#
# Found tweet by: @suntimesobits
# 22
#
#
# Found tweet by: @jellesdejong
# 23
#
#
# Found tweet by: @ceeyahnow
# 24
#
#
# Found tweet by: @tweeeteeepies
# 25
#
#
# Found tweet by: @DartDClark
# 26
#
#
# Found tweet by: @alphabreed2016
# 27
#
#
# Found tweet by: @Veva75991915
# 28
#
#
# Found tweet by: @djoneman
# 29
#
#
# Found tweet by: @kaurwn
# 30
#
#
# Found tweet by: @JassieMortimer
# 31
#
#
# Found tweet by: @RalfMarsault
# 32
#
#
# Found tweet by: @JulianaNein9
# 33
#
#
# Found tweet by: @nancy_rendell
# 34
#
#
# Found tweet by: @Mavsgirl4real
# 35
#
#
# Found tweet by: @CJBesch
# 36
#
#
# Found tweet by: @MCKENNA_60
# 37
#
#
# Found tweet by: @jonmerrickwrite
# 38
#
#
# Found tweet by: @pureamphigory
# 39
#
#
# Found tweet by: @TheSliverEllie
# 40
#
#
# Found tweet by: @emilyy_smithh24
# 41
#
#
# Found tweet by: @kkphoney
# 42
#
#
# Found tweet by: @wildjaden
# 43
#
#
# Found tweet by: @HeatherOsterman
# 44
#
#
# Found tweet by: @ZebulonMiletsky
# 45
#
#
# Found tweet by: @MrRoadSign
# 46
#
#
# Found tweet by: @Madrogator
# 47
#
#
# Found tweet by: @AmTrys
# 48
#
#
# Found tweet by: @newsobsessed
# 49
#
#
# Found tweet by: @freefromforces
# 50
#
#
# Found tweet by: @wendyddoublem
# 51
#
#
# Found tweet by: @CoachHenry123
# 52
#
#
# Found tweet by: @TXSportsMom
# 53
#
#
# Found tweet by: @AudreySugarsmak
# 54
#
#
# Found tweet by: @UniteWomenOrg
# 55
#
#
# Found tweet by: @Squidurassdown
# 56
#
#
# Found tweet by: @ladyed78
# 57
#
#
# Found tweet by: @annemargaretj
# 58
#
#
# Found tweet by: @ellyblue
# 59
#
#
# Found tweet by: @DanielleCC1
# 60
#
#
# Found tweet by: @KldsHackHealth
# 61
#
#
# Found tweet by: @KissAdDissAd
# 62
#
#
# Found tweet by: @ClearMindedness
# 63
#
#
# Found tweet by: @schulz_jason
# 64
#
#
# Found tweet by: @attrandome
# 65
#
#
# Found tweet by: @crystencurry
# 66
#
#
# Found tweet by: @TweetBenMax
# 67
#
#
# Found tweet by: @AuthorMiller09
# 68
#
#
# Found tweet by: @carlettej1
# 69
#
#
# Found tweet by: @RoosjeXS
# 70
#
#
# Found tweet by: @AhronZombi
# 71
#
#
# Found tweet by: @Audball12
# 72
#
#
# Found tweet by: @eugene_carmona
# 73
#
#
# Found tweet by: @Iheartlazydays
# 74
#
#
# Found tweet by: @swwcoop
# 75
#
#
# Found tweet by: @carlettej1
# 76
#
#
# Found tweet by: @harlechnnorfolk
# 77
#
#
# Found tweet by: @poorbabyboomer
# 78
#
#
# Found tweet by: @philipdavison
# 79
#
#
# Found tweet by: @RachelSilby
# 80
#
#
# Found tweet by: @HodeyHoe
# 81
#
#
# Found tweet by: @ladynobrow
# 82
#
#
# Found tweet by: @UWCampus
# 83
#
#
# Found tweet by: @UniteWomenCO
# 84
#
#
# Found tweet by: @C21Kdotdotdot
# 85
#
#
# Found tweet by: @maria__alexa
# 86
#
#
# Found tweet by: @coachdrewb
# 87
#
#
# Found tweet by: @TammeraLee
# 88
#
#
# Found tweet by: @ShannonDowney
# 89
#
#
# Found tweet by: @megoconnor13
# 90
#
#
# Found tweet by: @TheSeahawk
# 91
#
#
# Found tweet by: @mojobas
# 92
#
#
# Found tweet by: @HopeLoveWorld
# 93
#
#
# Found tweet by: @oh_elisabeth
# 94
#
#
# Found tweet by: @katesoup63
# 95
#
#
# Found tweet by: @AssemblageNYC
# 96
#
#
# Found tweet by: @seantkeenan
# 97
#
#
# Found tweet by: @SoniaMajeedCafe
# 98
#
#
# Found tweet by: @headlesseyes
# 99
#
#
# Found tweet by: @fayekutschman1
# 100
#
#
# Found tweet by: @ajanereis
# 101
#
#
# Found tweet by: @Paleophile
# 102
#
#
# Found tweet by: @GallopinDragons
# 103
#
#
# Found tweet by: @pink913
# 104
#
#
# Found tweet by: @DarrenMerrills
# 105
#
#
# Found tweet by: @SingerSoniaM
# 106
#
#
# Found tweet by: @lightchronic
# 107
#
#
# Found tweet by: @Paleophile
# 108
#
#
# Found tweet by: @sfpelosi
# 109
#
#
# Found tweet by: @SoniaMajeedFC
# 110
#
#
# Found tweet by: @super_blessed21
# 111
#
#
# Found tweet by: @ClearMindedness
# 112
#
#
# Found tweet by: @RickyBird11811
# 113
#
#
# Found tweet by: @Microcosmmm
# 114
#
#
# Found tweet by: @Ahlephia
# 115
#
#
# Found tweet by: @Archangel0414
# 116
#
#
# Found tweet by: @Adestria3
# 117
#
#
# Found tweet by: @ArianeBellamar
# 118
#
#
# Found tweet by: @nolaprncs
# 119
#
#
# Found tweet by: @JimKubrick
# 120
#
#
# Found tweet by: @ann_seal
# 121
#
#
# Found tweet by: @BarbOSEAC
# 122
#
#
# Found tweet by: @SpookyMrsGreen
# 123
#
#
# Found tweet by: @XenobiaTen
# 124
#
#
# Found tweet by: @bbcherrytomato
# 125
#
#
# Found tweet by: @d_bulla
# 126
#
#
# Found tweet by: @FuzzWolfCA
# 127
#
#
# Found tweet by: @fionnsadidas
# 128
#
#
# Found tweet by: @Progress4OHIO1
# 129
#
#
# Found tweet by: @emashmorex
# 130
#
#
# Found tweet by: @LarryvilleLaw1
# 131
#
#
# Found tweet by: @brandicejeanine
# 132
#
#
# Found tweet by: @akakrissie
# 133
#
#
# Found tweet by: @themenads
# 134
#
#
# Found tweet by: @LeeAlso
# 135
#
#
# Found tweet by: @dare2misbehave
# 136
#
#
# Found tweet by: @tebenas
# 137
#
#
# Found tweet by: @GoonerGimli
# 138
#
#
# Found tweet by: @ArianeBellamar
# 139
#
#
# Found tweet by: @poorbabyboomer
# 140
#
#
# Found tweet by: @tebenas
# 141
#
#
# Found tweet by: @adgrad
# 142
#
#
# Found tweet by: @McKPR
# 143
#
#
# Found tweet by: @smileatstyle
# 144
#
#
# Found tweet by: @FalahiShahid
# 145
#
#
# Found tweet by: @LynnSerafinn
# 146
#
#
# Found tweet by: @sallycozens
# 147
#
#
# Found tweet by: @ElkonJames
# 148
#
#
# Found tweet by: @kaythegod3
# 149
#
#
# Found tweet by: @DJSailorMan
# 150
#
#
# Found tweet by: @retinolalpha
# 151
#
#
# Found tweet by: @projectmaven
# 152
#
#
# Found tweet by: @YingYangMind
# 153
#
#
# Found tweet by: @AGoadEsq
# 154
#
#
# Found tweet by: @Lglwry
# 155
#
#
# Found tweet by: @succordiggs
# 156
#
#
# Found tweet by: @JNewtonHowes
# 157
#
#
# Found tweet by: @LINDYARIFF
# 158
#
#
# Found tweet by: @thomaslansink1
# 159
#
#
# Found tweet by: @JackHarringto20
# 160
#
#
# Found tweet by: @ArianeBellamar
# 161
#
#
# Found tweet by: @sabesimpson1
# 162
#
#
# Found tweet by: @vvlcanspock
# 163
#
#
# Found tweet by: @SwaggBundlez
# 164
#
#
# Found tweet by: @UUA
# 165
#
#
# Found tweet by: @LaurieCopland
# 166
#
#
# Found tweet by: @xelu3banh
# 167
#
#
# Found tweet by: @OPB
# 168
#
#
# Found tweet by: @JackHarringto20
# 169
#
#
# Found tweet by: @JanetEHutchins
# 170
#
#
# Found tweet by: @aixiemae
# 171
#
#
# Found tweet by: @chaos_oxymoron
# 172
#
#
# Found tweet by: @tayy_sims
# 173
#
#
# Found tweet by: @Belegedan
# 174
#
#
# Found tweet by: @hudsonliberty
# 175
#
#
# Found tweet by: @Edu12563
# 176
#
#
# Found tweet by: @MaudL
# 177
#
#
# Found tweet by: @chaos_oxymoron
# 178
#
#
# Found tweet by: @LadyBReal1
# 179
#
#
# Found tweet by: @theastroJoker
# 180
#
#
# Found tweet by: @my2cnz
# 181
#
#
# Found tweet by: @JSolRogue
# 182
#
#
# Found tweet by: @UnterdenTeppich
# 183
#
#
# Found tweet by: @hashtagthatnow
# 184
#
#
# Found tweet by: @Abu_Taymi
# 185
#
#
# Found tweet by: @higginsgggg
# 186
#
#
# Found tweet by: @DebiRatliffe
# 187
#
#
# Found tweet by: @ohnoitslex
# 188
#
#
# Found tweet by: @BKNationOrg
# 189
#
#
# Found tweet by: @BKNationOrg
# 190
#
#
# Found tweet by: @bsnbrysp8
# 191
#
#
# Found tweet by: @BeckyAdams971
# 192
#
#
# Found tweet by: @beepea
# 193
#
#
# Found tweet by: @RzrbckRed
# 194
#
#
# Found tweet by: @BKNationOrg
# 195
#
#
# Found tweet by: @OurVerity
# 196
#
#
# Found tweet by: @whiteribbon
# 197
#
#
# Found tweet by: @sharpieblue
# 198
#
#
# Found tweet by: @Nate_ready2go
# 199
#
#
# Found tweet by: @BKNationOrg
# 200
#
#
# Found tweet by: @_MichaelaMiles
# 201
#
#
# Found tweet by: @_Its_Just_J
# 202
#
#
# Found tweet by: @journo_abheet
# 203
#
#
# Found tweet by: @Tinabell05
# 204
#
#
# Found tweet by: @BKNationOrg
# 205
#
#
# Found tweet by: @MonopointAmy
# 206
#
#
# Found tweet by: @chrishac2796
# 207
#
#
# Found tweet by: @Dennis_n_Lyrics
# 208
#
#
# Found tweet by: @BKNationOrg
# 209
#
#
# Found tweet by: @8675309Carson
# 210
#
#
# Found tweet by: @paranoidpal
# 211
#
#
# Found tweet by: @Tinabell05
# 212
#
#
# Found tweet by: @BKNationOrg
# 213
#
#
# Found tweet by: @stitchesbekrazy
# 214
#
#
# Found tweet by: @ASIMALTRATONO
# 215
#
#
# Found tweet by: @SpeakOut4Others
# 216
#
#
# Found tweet by: @ExpressionTees
# 217
#
#
# Found tweet by: @denisebossert
# 218
#
#
# Found tweet by: @kevinjayheldman
# 219
#
#
# Found tweet by: @thisgirlkel
# 220
#
#
# Found tweet by: @GenderChat
# 221
#
#
# Found tweet by: @BKNationOrg
# 222
#
#
# Found tweet by: @track41
# 223
#
#
# Found tweet by: @AssmaaAlmaairgy
# 224
#
#
# Found tweet by: @allanbrauer
# 225
#
#
# Found tweet by: @BKNationOrg
# 226
#
#
# Found tweet by: @spoonie_style
# 227
#
#
# Found tweet by: @BKNationOrg
# 228
#
#
# Found tweet by: @armsivilli
# 229
#
#
# Found tweet by: @BKNationOrg
# 230
#
#
# Found tweet by: @jackiecall3
# 231
#
#
# Found tweet by: @KingBEEH
# 232
#
#
# Found tweet by: @BKNationOrg
# 233
#
#
# Found tweet by: @BasedOhioGuy
# 234
#
#
# Found tweet by: @BKNationOrg
# 235
#
#
# Found tweet by: @BKNationOrg
# 236
#
#
# Found tweet by: @franksan240
# 237
#
#
# Found tweet by: @BKNationOrg
# 238
#
#
# Found tweet by: @sfpelosi
# 239
#
#
# Found tweet by: @BKNationOrg
# 240
# Found tweet by: @T_N_Angel
# 241
#
#
# Found tweet by: @BKNationOrg
# 242
#
#
# Found tweet by: @XSTActual
# 243
#
#
# Found tweet by: @BKNationOrg
# 244
#
#
# Found tweet by: @SuperJohn100755
# 245
#
#
# Found tweet by: @pxbern
# 246
#
#
# Found tweet by: @kiki00312
# 247
#
#
# Found tweet by: @FrankLicari
# 248
#
#
# Found tweet by: @BKNationOrg
# 249
#
#
# Found tweet by: @ashleighglazer
# 250
#
#
# Found tweet by: @Truthaccordng2b
# 251
#
#
# Found tweet by: @BKNationOrg
# 252
#
#
# Found tweet by: @MissMolly3103
# 253
#
#
# Found tweet by: @OaktownPirate
# 254
#
#
# Found tweet by: @XenobiaTen
# 255
#
#
# Found tweet by: @spoonie_style
# 256
#
#
# Found tweet by: @BKNationOrg
# 257
#
#
# Found tweet by: @PeterStoughton1
# 258
#
#
# Found tweet by: @BKNationOrg
# 259
#
#
# Found tweet by: @kelmoelit
# 260
#
#
# Found tweet by: @BKNationOrg
# 261
#
#
# Found tweet by: @setislady
# 262
#
#
# Found tweet by: @BKNationOrg
# 263
#
#
# Found tweet by: @oko_mary
# 264
#
#
# Found tweet by: @BKNationOrg
# 265
#
#
# Found tweet by: @lallullila
# 266
#
#
# Found tweet by: @BKNationOrg
# 267
#
#
# Found tweet by: @AmerikkKAIsDead
# 268
#
#
# Found tweet by: @BKNationOrg
# 269
#
#
# Found tweet by: @BKNationOrg
# 270
#
#
# Found tweet by: @BKNationOrg
# 271
#
#
# Found tweet by: @RoseValdes4
# 272
#
#
# Found tweet by: @BKNationOrg
# 273
#
#
# Found tweet by: @BKNationOrg
# 274
#
#
# Found tweet by: @KittenMcKays
# 275
#
#
# Found tweet by: @AineMcGlynn
# 276
#
#
# Found tweet by: @dee_d35
# 277
#
#
# Found tweet by: @BKNationOrg
# 278
#
#
# Found tweet by: @TeenyWarrior
# 279
#
#
# Found tweet by: @terrihartley
# 280
#
#
# Found tweet by: @_TomBright
# 281
#
#
# Found tweet by: @stikklebrix
# 282
#
#
# Found tweet by: @BKNationOrg
# 283
#
#
# Found tweet by: @MarjorieBritt20
# 284
#
#
# Found tweet by: @DawnDHRDRCH
# 285
#
#
# Found tweet by: @OsaGz
# 286
#
#
# Found tweet by: @Justintime8519
# 287
#
#
# Found tweet by: @BKNationOrg
# 288
#
#
# Found tweet by: @DanielKeene92
# 289
#
#
# Found tweet by: @booboodip
# 290
#
#
# Found tweet by: @sussim13
# 291
#
#
# Found tweet by: @BroadAgenda5050
# 292
#
#
# Found tweet by: @TTLLDcom
# 293
#
#
# Found tweet by: @chaos_oxymoron
# 294
#
#
# Found tweet by: @tvldiva
# 295
#
#
# Found tweet by: @BKNationOrg
# 296
#
#
# Found tweet by: @CandyClarkWilli
# 297
#
#
# Found tweet by: @Plantsmantx
# 298
#
#
# Found tweet by: @BKNationOrg
# 299
#
#
# Found tweet by: @jenpurdie
# 300
#
#
# Found tweet by: @RVAStreetMedia
# 301
#
#
# Found tweet by: @BKNationOrg
# 302
#
#
# Found tweet by: @briamonaeeee
# 303
#
#
# Found tweet by: @DanSchindel
# 304
#
#
# Found tweet by: @Kat4Obama
# 305
#
#
# Found tweet by: @GvngMattersCFMT
# 306
#
#
# Found tweet by: @BKNationOrg
# 307
#
#
# Found tweet by: @Yramattakumah
# 308
#
#
# Found tweet by: @BKNationOrg
# 309
#
#
# Found tweet by: @RedheadCommando
# 310
#
#
# Found tweet by: @_NajaFxCknBaby
# 311
#
#
# Found tweet by: @BKNationOrg
# 312
#
#
# Found tweet by: @FernHillSudio
# 313
#
#
# Found tweet by: @BKNationOrg
# 314
#
#
# Found tweet by: @CoreyChadwick2
# 315
#
#
# Found tweet by: @BKNationOrg
# 316
#
#
# Found tweet by: @bizlunchbox
# 317
#
#
# Found tweet by: @BKNationOrg
# 318
#
#
# Found tweet by: @aheadonapillow
# 319
#
#
# Found tweet by: @BKNationOrg
# 320
#
#
# Found tweet by: @annemargaretj
# 321
#
#
# Found tweet by: @BKNationOrg
# 322
#
#
# Found tweet by: @BKNationOrg
# 323
#
#
# Found tweet by: @Tenn_Guy
# 324
#
#
# Found tweet by: @BKNationOrg
# 325
#
#
# Found tweet by: @itsJustWMac
# 326
#
#
# Found tweet by: @BKNationOrg
# 327
#
#
# Found tweet by: @CrazyCatRescuer
# 328
#
#
# Found tweet by: @BKNationOrg
# 329
#
#
# Found tweet by: @BKNationOrg
# 330
#
#
# Found tweet by: @robinv016
# 331
#
#
# Found tweet by: @ng_480
# 332
#
#
# Found tweet by: @BKNationOrg
# 333
#
#
# Found tweet by: @lisamarie_bee
# 334
#
#
# Found tweet by: @FunkyTeeZ
# 335
#
#
# Found tweet by: @BKNationOrg
# 336
#
#
# Found tweet by: @BKNationOrg
# 337
#
#
# Found tweet by: @BKNationOrg
# 338
#
#
# Found tweet by: @Martin33592259
# 339
#
#
# Found tweet by: @ElisaWilding
# 340
#
#
# Found tweet by: @BKNationOrg
# 341
#
#
# Found tweet by: @bella_carrab
# 342
#
#
# Found tweet by: @ToddToddlbarnes
# 343
#
#
# Found tweet by: @BadRedheadMedia
# 344
#
#
# Found tweet by: @tbprising
# 345
#
#
# Found tweet by: @jinjuinfo
# 346
#
#
# Found tweet by: @lizalathrum_
# 347
#
#
# Found tweet by: @CommodoreNelson
# 348
#
#
# Found tweet by: @rosemfrench
# 349
#
#
# Found tweet by: @perry3220
# 350
#
#
# Found tweet by: @authenticpaint
# 351
#
#
# Found tweet by: @mnemoneis
# 352
#
#
# Found tweet by: @LibertyRanger
# 353
#
#
# Found tweet by: @waltb31
# 354
#
#
# Found tweet by: @mharvey816
# 355
#
#
# Found tweet by: @cecilyvanzandt
# 356
#
#
# Found tweet by: @Resist4HOPE
# 357
#
#
# Found tweet by: @Gendersolid
# 358
#
#
# Found tweet by: @sfpelosi
# 359
#
#
# Found tweet by: @TrampDavisAlive
# 360
#
#
# Found tweet by: @jferraioloveri1
# 361
#
#
# Found tweet by: @PeaceOvrViolnce
# 362
#
#
# Found tweet by: @Martin33592259
# 363
#
#
# Found tweet by: @AMeierBourdeau
# 364
#
#
# Found tweet by: @elevenbravo138
# 365
#
#
# Found tweet by: @klralms
# 366
#
#
# Found tweet by: @abrrx
# 367
#
#
# Found tweet by: @JustMeLeChanel
# 368
#
#
# Found tweet by: @Artemis652
# 369
#
#
# Found tweet by: @JBiebersfan23
# 370
#
#
# Found tweet by: @jojo021121
# 371
#
#
# Found tweet by: @altaweelsamah
# 372
#
#
# Found tweet by: @SableFilms
# 373
#
#
# Found tweet by: @TrumpUnfit2Serv
# 374
#
#
# Found tweet by: @elizebethtown
# 375
#
#
# Found tweet by: @aloeverawangg
# 376
#
#
# Found tweet by: @RiveraGrrl
# 377
#
#
# Found tweet by: @helensmomma
# 378
#
#
# Found tweet by: @MissGambinoGirl
# 379
#
#
# Found tweet by: @anukasan1977
# 380
#
#
# Found tweet by: @smithjanelv
# 381
#
#
# Found tweet by: @AstonsOtterTwin
# 382
#
#
# Found tweet by: @HopeLoveWorld
# 383
#
#
# Found tweet by: @anitalarkens
# 384
#
#
# Found tweet by: @ZonaHotWings
# 385
#
#
# Found tweet by: @World_Of_Hurt
# 386
#
#
# Found tweet by: @talkofct
# 387
#
#
# Found tweet by: @FoxyFacade
# 388
#
#
# Found tweet by: @JulianY8s
# 389
#
#
# Found tweet by: @RiveraGrrl
# 390
#
#
# Found tweet by: @nataliestatham
# 391
#
#
# Found tweet by: @Burndawg
# 392
#
#
# Found tweet by: @MLKCLC
# 393
#
#
# Found tweet by: @yuliapopova
# 394
#
#
# Found tweet by: @AnOpenRoadCast
# 395
#
#
# Found tweet by: @SandyKnow1
# 396
#
#
# Found tweet by: @ch3rylanns
# 397
#
#
# Found tweet by: @TaraLuu
# 398
#
#
# Found tweet by: @PoPpYsMiSsiOn
# 399
#
#
# Found tweet by: @Liberty_Uno
# 400
#
#
# Found tweet by: @TheBFRoom
# 401
#
#
# Found tweet by: @bjportraits
# 402
#
#
# Found tweet by: @MaryCipolla3
# 403
#
#
# Found tweet by: @queenbprods
# 404
#
#
# Found tweet by: @JPrice02
# 405
#
#
# Found tweet by: @JoannWayman
# 406
#
#
# Found tweet by: @queenbprods
# 407
#
#
# Found tweet by: @Cronewomanchane
# 408
#
#
# Found tweet by: @jey_jams
# 409
#
#
# Found tweet by: @makilingmiracle
# 410
#
#
# Found tweet by: @WorldConserv
# 411
#
#
# Found tweet by: @ay0dele
# 412
#
#
# Found tweet by: @BumInChief
# 413
#
#
# Found tweet by: @kerryherbert007
# 414
#
#
# Found tweet by: @IAmLuckyCharms5
# 415
#
#
# Found tweet by: @wherepond
# 416
#
#
# Found tweet by: @trikileaks
# 417
#
#
# Found tweet by: @its_allice
# 418
#
#
# Found tweet by: @SJTokyo
# 419
#
#
# Found tweet by: @BumInChief
# 420
#
#
# Found tweet by: @ClaudiaRMoreno
# 421
#
#
# Found tweet by: @IWillRedPillYou
# 422
#
#
# Found tweet by: @IWillRedPillYou
# 423
#
#
# Found tweet by: @BumInChief
# 424
#
#
# Found tweet by: @Lorechile
# 425
#
#
# Found tweet by: @Pastelistaz
# 426
#
#
# Found tweet by: @JPrice02
# 427
#
#
# Found tweet by: @Madrogator
# 428
#
#
# Found tweet by: @OMGitskyri
# 429
#
#
# Found tweet by: @kyle_neso
# 430
#
#
# Found tweet by: @smellwhatherock
# 431
#
#
# Found tweet by: @xokayizzyx
# 432
#
#
# Found tweet by: @ScottyNotHotty
# 433
#
#
# Found tweet by: @Studio746
# 434
#
#
# Found tweet by: @smellwhatherock
# 435
#
#
# Found tweet by: @LiberalResist
# 436
#
#
# Found tweet by: @Fragola_Girl
# 437
#
#
# Found tweet by: @lumimichelle
# 438
#
#
# Found tweet by: @teilafox
# 439
#
#
# Found tweet by: @TaylorFoxSmith3
# 440
#
#
# Found tweet by: @TomWellborn
# 441
#
#
# Found tweet by: @Happyheart411
# 442
#
#
# Found tweet by: @oblakistas
# 443
#
#
# Found tweet by: @usertrueist
# 444
#
#
# Found tweet by: @TomWellborn
# 445
#
#
# Found tweet by: @denisparra
# 446
#
#
# Found tweet by: @voltaire
# 447
#
#
# Found tweet by: @HealingWSpirit
# 448
#
#
# Found tweet by: @JessedHagopian
# 449
#
#
# Found tweet by: @QuesadillarKing
# 450
#
#
# Found tweet by: @indivisibleden
# 451
#
#
# Found tweet by: @Irishkami
# 452
#
#
# Found tweet by: @DanielReports
# 453
#
#
# Found tweet by: @Flora_Guara
# 454
#
#
# Found tweet by: @AFTunion
# 455
#
#
# Found tweet by: @Michell66010778
# 456
#
#
# Found tweet by: @Saturday_Onafa
# 457
#
#
# Found tweet by: @Baby_Xmas
# 458
#
#
# Found tweet by: @CaeliLa
# 459
#
#
# Found tweet by: @crixlee
# 460
#
#
# Found tweet by: @thisgirlkel
# 461
#
#
# Found tweet by: @BScotTanner
# 462
#
#
# Found tweet by: @AMFMInfo
# 463
#
#
# Found tweet by: @LeggoWorld
# 464
#
#
# Found tweet by: @Saturday_Onafa
# 465
#
#
# Found tweet by: @jjpearson64
# 466
#
#
# Found tweet by: @RoWithit
# 467
#
#
# Found tweet by: @RightingWrong
# 468
#
#
# Found tweet by: @HarmonizePod
# 469
#
#
# Found tweet by: @Mikesonbeek
# 470
#
#
# Found tweet by: @legend_bird
# 471
#
#
# Found tweet by: @ClaremKaye
# 472
#
#
# Found tweet by: @cerebralsymphoy
# 473
#
#
# Found tweet by: @gladysurvivor
# 474
#
#
# Found tweet by: @nasapphics
# 475
#
#
# Found tweet by: @Peabots13
# 476
#
#
# Found tweet by: @Fadhilow
# 477
#
#
# Found tweet by: @2Rarely
# 478
#
#
# Found tweet by: @bossplaya7
# 479
#
#
# Found tweet by: @AliceCoven
# 480
# Found tweet by: @MrSahiraPerez
# 481
#
#
# Found tweet by: @lorena_berna
# 482
#
#
# Found tweet by: @JessicaGenius
# 483
#
#
# Found tweet by: @anotherNYCwoman
# 484
#
#
# Found tweet by: @nikrichie
# 485
#
#
# Found tweet by: @BigMoneyTraders
# 486
#
#
# Found tweet by: @pchultimate
# 487
#
#
# Found tweet by: @angitel
# 488
#
#
# Found tweet by: @laurielaker
# 489
#
#
# Found tweet by: @MightyAlwayz
# 490
#
#
# Found tweet by: @IKasidit
# 491
#
#
# Found tweet by: @redheadedwitch2
# 492
#
#
# Found tweet by: @blondelena
# 493
#
#
# Found tweet by: @pyz30
# 494
#
#
# Found tweet by: @1a
# 495
#
#
# Found tweet by: @moose_taz
# 496
#
#
# Found tweet by: @minciunaria
# 497
#
#
# Found tweet by: @TeddyNails
# 498
#
#
# Found tweet by: @RightingWrong
# 499
#
#
# Found tweet by: @JIFF01
# 500
#
#
# Found tweet by: @RMASpears
# 501
#
#
# Found tweet by: @NadaRam600
# 502
#
#
# Found tweet by: @qz
# 503
#
#
# Found tweet by: @zibahnwako
# 504
#
#
# Found tweet by: @beautyanchor
# 505
#
#
# Found tweet by: @89VWGolf
# 506
#
#
# Found tweet by: @JemsOpal
# 507
#
#
# Found tweet by: @TRENCHCOATx
# 508
#
#
# Found tweet by: @oldtrooper75
# 509
#
#
# Found tweet by: @AshTheMc
# 510
#
#
# Found tweet by: @textymcberto
# 511
#
#
# Found tweet by: @akhgal
# 512
#
#
# Found tweet by: @somethingldsay
# 513
#
#
# Found tweet by: @ianpaulcassidy
# 514
#
#
# Found tweet by: @crys_towers
# 515
#
#
# Found tweet by: @Happyheart411
# 516
#
#
# Found tweet by: @hannahhthomp1
# 517
#
#
# Found tweet by: @TurningPointYRK
# 518
#
#
# Found tweet by: @madblack65
# 519
#
#
# Found tweet by: @TomWellborn
# 520
#
#
# Found tweet by: @aOverit
# 521
#
#
# Found tweet by: @jellyfish_guy
# 522
#
#
# Found tweet by: @izharnephrol
# 523
#
#
# Found tweet by: @saralivadeas
# 524
#
#
# Found tweet by: @chicpeakandbe
# 525
#
#
# Found tweet by: @BienvidaE
# 526
#
#
# Found tweet by: @_Missy13
# 527
#
#
# Found tweet by: @Marta8th
# 528
#
#
# Found tweet by: @SandyKnow1
# 529
#
#
# Found tweet by: @NlkolsonAlfrets
# 530
#
#
# Found tweet by: @teresarothwell
# 531
#
#
# Found tweet by: @TurningPointYRK
# 532
#
#
# Found tweet by: @CynthiaCirile
# 533
#
#
# Found tweet by: @kerryherbert007
# 534
#
#
# Found tweet by: @CTalmon
# 535
#
#
# Found tweet by: @madblack65
# 536
#
#
# Found tweet by: @violetknockout
# 537
#
#
# Found tweet by: @RRanswers
# 538
#
#
# Found tweet by: @CorporatePiggie
# 539
#
#
# Found tweet by: @uncle2u
# 540
#
#
# Found tweet by: @UsaamaK
# 541
#
#
# Found tweet by: @JohnLambo4
# 542
#
#
# Found tweet by: @staradvocates
# 543
#
#
# Found tweet by: @CorporatePiggie
# 544
#
#
# Found tweet by: @bountyofbeads2
# 545
#
#
# Found tweet by: @TheHateDetector
# 546
#
#
# Found tweet by: @RobertClaypool6
# 547
#
#
# Found tweet by: @PeterCarlinoCPA
# 548
#
#
# Found tweet by: @DanielReports
# 549
#
#
# Found tweet by: @richardluddite
# 550
#
#
# Found tweet by: @LauraHM8
# 551
#
#
# Found tweet by: @JackWarner16
# 552
#
#
# Found tweet by: @BooBooPenners
# 553
#
#
# Found tweet by: @lise_andreasen
# 554
#
#
# Found tweet by: @LegacyofGena
# 555
#
#
# Found tweet by: @smargerhita
# 556
#
#
# Found tweet by: @pippaliciousj
# 557
#
#
# Found tweet by: @BooBooPenners
# 558
#
#
# Found tweet by: @Junkmale73
# 559
#
#
# Found tweet by: @Diletta_Luna
# 560
#
#
# Found tweet by: @xXxstefan
# 561
#
#
# Found tweet by: @EmilyKilheeney
# 562
#
#
# Found tweet by: @lise_andreasen
# 563
#
#
# Found tweet by: @eagles1229
# 564
#
#
# Found tweet by: @MelsAngelBard
# 565
#
#
# Found tweet by: @smellwhatherock
# 566
#
#
# Found tweet by: @RahamRaf
# 567
#
#
# Found tweet by: @LaurenHolmes_
# 568
#
#
# Found tweet by: @dondickson
# 569
#
#
# Found tweet by: @FiredUpInLV2
# 570
#
#
# Found tweet by: @FamilyLawD
# 571
#
#
# Found tweet by: @Annie_Devine
# 572
#
#
# Found tweet by: @kellymason07
# 573
#
#
# Found tweet by: @RoseStokes
# 574
#
#
# Found tweet by: @BooBooPenners
# 575
#
#
# Found tweet by: @imeverywoman7
# 576
#
#
# Found tweet by: @spikedonline
# 577
#
#
# Found tweet by: @Wonder_Lynne
# 578
#
#
# Found tweet by: @Kate_Is_Rising
# 579
#
#
# Found tweet by: @socialbterfly
# 580
#
#
# Found tweet by: @marcar555
# 581
#
#
# Found tweet by: @AsiaAdams21
# 582
#
#
# Found tweet by: @Junkmale73
# 583
#
#
# Found tweet by: @Littles_360
# 584
#
#
# Found tweet by: @AnneBini
# 585
#
#
# Found tweet by: @ligergirl13
# 586
#
#
# Found tweet by: @KegHammered
# 587
#
#
# Found tweet by: @MosesDidItBest
# 588
#
#
# Found tweet by: @PattyAshley03
# 589
#
#
# Found tweet by: @johnwalisswag
# 590
#
#
# Found tweet by: @MyRoomCam69
# 591
#
#
# Found tweet by: @thestopbutton
# 592
#
#
# Found tweet by: @RahamRaf
# 593
#
#
# Found tweet by: @bethcbridge
# 594
#
#
# Found tweet by: @Redmant66
# 595
#
#
# Found tweet by: @MykiAngeline
# 596
#
#
# Found tweet by: @madblack65
# 597
#
#
# Found tweet by: @Gregory_Malchuk
# 598
#
#
# Found tweet by: @SMKGBELLA
# 599
#
#
# Found tweet by: @BooBooPenners
# 600
#
#
# Found tweet by: @PeterStoughton1
# 601
#
#
# Found tweet by: @Jessica66166126
# 602
#
#
# Found tweet by: @PostWorldNews
# 603
#
#
# Found tweet by: @heatherjross
# 604
#
#
# Found tweet by: @BooBooPenners
# 605
#
#
# Found tweet by: @madblack65
# 606
#
#
# Found tweet by: @Redmant66
# 607
#
#
# Found tweet by: @madblack65
# 608
#
#
# Found tweet by: @JeannineStehlin
# 609
#
#
# Found tweet by: @TDubb
# 610
#
#
# Found tweet by: @BooBooPenners
# 611
#
#
# Found tweet by: @TeresaFogelberg
# 612
#
#
# Found tweet by: @Rape_is_Real
# 613
#
#
# Found tweet by: @ChanelleTeresa
# 614
#
#
# Found tweet by: @Mugmaz
# 615
#
#
# Found tweet by: @LucyJParry
# 616
#
#
# Found tweet by: @StonewallGaztte
# 617
#
#
# Found tweet by: @tomasrabago1
# 618
#
#
# Found tweet by: @WomenPromo
# 619
#
#
# Found tweet by: @fylgiafylgia
# 620
#
#
# Found tweet by: @MotherEarthHH
# 621
#
#
# Found tweet by: @doctorschmitty
# 622
#
#
# Found tweet by: @ubervaper
# 623
#
#
# Found tweet by: @Irishjenn2005
# 624
#
#
# Found tweet by: @WLTribune
# 625
#
#
# Found tweet by: @ThurgaKana
# 626
#
#
# Found tweet by: @jeepeg
# 627
#
#
# Found tweet by: @lindabogan62
# 628
#
#
# Found tweet by: @HvnlyQn1
# 629
#
#
# Found tweet by: @WepHove
# 630
#
#
# Found tweet by: @madblack65
# 631
#
#
# Found tweet by: @queerlycontent
# 632
#
#
# Found tweet by: @TOTigerLilly
# 633
#
#
# Found tweet by: @simeonberry
# 634
#
#
# Found tweet by: @BooBooPenners
# 635
#
#
# Found tweet by: @LauraQuevedo_9
# 636
#
#
# Found tweet by: @naufrage_a
# 637
#
#
# Found tweet by: @OrkidB
# 638
#
#
# Found tweet by: @ms_nelsonville
# 639
#
#
# Found tweet by: @madblack65
# 640
#
#
# Found tweet by: @CardoInFiore
# 641
#
#
# Found tweet by: @Emy_Phenix
# 642
#
#
# Found tweet by: @Penissaurus_Rex
# 643
#
#
# Found tweet by: @JamesHartman3
# 644
#
#
# Found tweet by: @TheLittleDaleks
# 645
#
#
# Found tweet by: @joollsboothgb
# 646
#
#
# Found tweet by: @katielmerrick
# 647
#
#
# Found tweet by: @madblack65
# 648
#
#
# Found tweet by: @95bFMNews
# 649
#
#
# Found tweet by: @StopSamir
# 650
#
#
# Found tweet by: @TheLittleDaleks
# 651
#
#
# Found tweet by: @Ines_2597
# 652
#
#
# Found tweet by: @ThatVDOVault
# 653
#
#
# Found tweet by: @PittsonWalter
# 654
#
#
# Found tweet by: @VadiHolding
# 655
#
#
# Found tweet by: @helenehrenhofer
# 656
#
#
# Found tweet by: @PietGamelkoorn
# 657
#
#
# Found tweet by: @BooBooPenners
# 658
#
#
# Found tweet by: @Altered999
# 659
#
#
# Found tweet by: @the_wimn
# 660
#
#
# Found tweet by: @rnsills
# 661
#
#
# Found tweet by: @ceciledelarue
# 662
#
#
# Found tweet by: @AmyMargaretWrig
# 663
#
#
# Found tweet by: @dulger_s
# 664
#
#
# Found tweet by: @missdaisssyy
# 665
#
#
# Found tweet by: @jordanbaglivi
# 666
#
#
# Found tweet by: @BDittmar
# 667
#
#
# Found tweet by: @Devonkopec
# 668
#
#
# Found tweet by: @SocialDefault
# 669
#
#
# Found tweet by: @hkeybsg
# 670
#
#
# Found tweet by: @Inkydelaware
# 671
#
#
# Found tweet by: @BooBooPenners
# 672
#
#
# Found tweet by: @TheLittleDaleks
# 673
#
#
# Found tweet by: @Richardhurst19
# 674
#
#
# Found tweet by: @Richardhurst19
# 675
#
#
# Found tweet by: @kushkandy95
# 676
#
#
# Found tweet by: @msnbme
# 677
#
#
# Found tweet by: @redwardprice719
# 678
#
#
# Found tweet by: @Timmy2Joints
# 679
#
#
# Found tweet by: @Phoebe1_
# 680
#
#
# Found tweet by: @KANGMASBO
# 681
#
#
# Found tweet by: @aboew016
# 682
#
#
# Found tweet by: @CaeruleanSea
# 683
#
#
# Found tweet by: @Cam_YouDigIt
# 684
#
#
# Found tweet by: @queensbriane
# 685
#
#
# Found tweet by: @sayitisnottrue
# 686
#
#
# Found tweet by: @EAGLEjme
# 687
#
#
# Found tweet by: @WhoIsDEF
# 688
#
#
# Found tweet by: @SafeHavenNtwk
# 689
#
#
# Found tweet by: @Jessica66166126
# 690
#
#
# Found tweet by: @rationalreview
# 691
#
#
# Found tweet by: @jadeconcannon
# 692
#
#
# Found tweet by: @virginia_house
# 693
#
#
# Found tweet by: @TheLittleDaleks
# 694
#
#
# Found tweet by: @jonmspangler
# 695
#
#
# Found tweet by: @TybeeTV
# 696
#
#
# Found tweet by: @JenniferViera9
# 697
#
#
# Found tweet by: @tonijannotta
# 698
#
#
# Found tweet by: @johnnywike
# 699
#
#
# Found tweet by: @GrumpyKate1978
# 700
#
#
# Found tweet by: @Glitchy_Ashburn
# 701
#
#
# Found tweet by: @khiarica
# 702
#
#
# Found tweet by: @teracek111
# 703
#
#
# Found tweet by: @carynhunt
# 704
#
#
# Found tweet by: @TheLittleDaleks
# 705
#
#
# Found tweet by: @happier_better
# 706
#
#
# Found tweet by: @clovertouchaus
# 707
#
#
# Found tweet by: @ArianeBellamar
# 708
#
#
# Found tweet by: @pastorcarolt
# 709
#
#
# Found tweet by: @TheLittleDaleks
# 710
#
#
# Found tweet by: @RKATAKA
# 711
#
#
# Found tweet by: @sjgeimer
# 712
#
#
# Found tweet by: @TAPSTRIMEDIA
# 713
#
#
# Found tweet by: @melsonite
# 714
#
#
# Found tweet by: @DraaBrown
# 715
#
#
# Found tweet by: @lawdotcom
# 716
#
#
# Found tweet by: @Panosfrmgoranos
# 717
#
#
# Found tweet by: @TheLittleDaleks
# 718
#
#
# Found tweet by: @TheLittleDaleks
# 719
#
#
# Found tweet by: @elizebethtown
# 720
# Found tweet by: @EzzaBowersNZ
# 721
#
#
# Found tweet by: @tkl277iztha1
# 722
#
#
# Found tweet by: @tweeeteeepies
# 723
#
#
# Found tweet by: @mclovinrules
# 724
#
#
# Found tweet by: @granny_st
# 725
#
#
# Found tweet by: @BroadAgenda5050
# 726
#
#
# Found tweet by: @letetiadj
# 727
#
#
# Found tweet by: @A_Tvisker
# 728
#
#
# Found tweet by: @LiselBruns
# 729
#
#
# Found tweet by: @xkidxjess
# 730
#
#
# Found tweet by: @SandraBognor
# 731
#
#
# Found tweet by: @lillyquintana7
# 732
#
#
# Found tweet by: @girlsreallyrule
# 733
#
#
# Found tweet by: @chazzyb31
# 734
#
#
# Found tweet by: @_kingtherapy
# 735
#
#
# Found tweet by: @markgkenny
# 736
#
#
# Found tweet by: @Women_on_IWD
# 737
#
#
# Found tweet by: @VeggieWanted
# 738
#
#
# Found tweet by: @NewCommGlobal
# 739
#
#
# Found tweet by: @ShrutznJ
# 740
#
#
# Found tweet by: @qbpnow
# 741
#
#
# Found tweet by: @sandraboo72
# 742
#
#
# Found tweet by: @inklesstales
# 743
#
#
# Found tweet by: @SheriBilderback
# 744
#
#
# Found tweet by: @ywdwarner
# 745
#
#
# Found tweet by: @JoseVezilier
# 746
#
#
# Found tweet by: @girlsreallyrule
# 747
#
#
# Found tweet by: @Chocola56256910
# 748
#
#
# Found tweet by: @SnydeBlogger
# 749
#
#
# Found tweet by: @Suey_geo
# 750
#
#
# Found tweet by: @fabulousmummy1
# 751
#
#
# Found tweet by: @tonniaagesen
# 752
#
#
# Found tweet by: @LisaMerloBooth
# 753
#
#
# Found tweet by: @GaimanRachel
# 754
#
#
# Found tweet by: @RunionW
# 755
#
#
# Found tweet by: @Harleigh_Swaine
# 756
#
#
# Found tweet by: @GHuangWA
# 757
#
#
# Found tweet by: @fightinjustic33
# 758
#
#
# Found tweet by: @FonkyChris
# 759
#
#
# Found tweet by: @CaeciliusEst
# 760
#
#
# Found tweet by: @lambpuff9
# 761
#
#
# Found tweet by: @clovertouchaus
# 762
#
#
# Found tweet by: @MelbaPeach_
# 763
#
#
# Found tweet by: @ThatVDOVault
# 764
#
#
# Found tweet by: @carleel143
# 765
#
#
# Found tweet by: @AuthorityBuildr
# 766
#
#
# Found tweet by: @ConsciousLifSum
# 767
#
#
# Found tweet by: @BuyThisPodcast
# 768
#
#
# Found tweet by: @MichaelKNeeley
# 769
#
#
# Found tweet by: @Neeley7
# 770
#
#
# Found tweet by: @ConSpeakPodcast
# 771
#
#
# Found tweet by: @scottjok
# 772
#
#
# Found tweet by: @catreeka
# 773
#
#
# Found tweet by: @Nitchola
# 774
#
#
# Found tweet by: @cass_w22
# 775
#
#
# Found tweet by: @HHudek
# 776
#
#
# Found tweet by: @nordenforever
# 777
#
#
# Found tweet by: @Mr_Cafferty
# 778
#
#
# Found tweet by: @blackcowboy333
# 779
#
#
# Found tweet by: @TheLittleDaleks
# 780
#
#
# Found tweet by: @MeneerRodrigo
# 781
#
#
# Found tweet by: @Carey09
# 782
#
#
# Found tweet by: @HKTaylor7
# 783
#
#
# Found tweet by: @SellingBySocial
# 784
#
#
# Found tweet by: @darkstarjujuz
# 785
#
#
# Found tweet by: @soundbitesiren
# 786
#
#
# Found tweet by: @soundbitesiren
# 787
#
#
# Found tweet by: @Davewellwisher
# 788
#
#
# Found tweet by: @Saun_Fischer
# 789
#
#
# Found tweet by: @Tiffanylbaldwin
# 790
#
#
# Found tweet by: @charmbaker
# 791
#
#
# Found tweet by: @BrianW189
# 792
#
#
# Found tweet by: @BrianW189
# 793
#
#
# Found tweet by: @comcast66
# 794
#
#
# Found tweet by: @sophieloupalmer
# 795
#
#
# Found tweet by: @c_pcpl
# 796
#
#
# Found tweet by: @LifeZette
# 797
#
#
# Found tweet by: @3veNadler
# 798
#
#
# Found tweet by: @mimi_saulino
# 799
#
#
# Found tweet by: @BSAatUVA
# 800
#
#
# Found tweet by: @debdean_dd
# 801
#
#
# Found tweet by: @MiseryXchord
# 802
#
#
# Found tweet by: @MrIanHitchings
# 803
#
#
# Found tweet by: @nvrqt
# 804
#
#
# Found tweet by: @nobigfoots
# 805
#
#
# Found tweet by: @SubwayShelley33
# 806
#
#
# Found tweet by: @CarboRaider
# 807
#
#
# Found tweet by: @CoachVolmer
# 808
#
#
# Found tweet by: @sex_abuse_news
# 809
#
#
# Found tweet by: @BohoBodyCo
# 810
#
#
# Found tweet by: @MrIanHitchings
# 811
#
#
# Found tweet by: @vmahabir97
# 812
#
#
# Found tweet by: @simonhoupt
# 813
#
#
# Found tweet by: @Raven_kittycat
# 814
#
#
# Found tweet by: @angeleenious
# 815
#
#
# Found tweet by: @kitkat232455
# 816
#
#
# Found tweet by: @AngryPhotoDude
# 817
#
#
# Found tweet by: @JA2_0
# 818
#
#
# Found tweet by: @JA2_0
# 819
#
#
# Found tweet by: @quebryant
# 820
#
#
# Found tweet by: @gonsosnews
# 821
#
#
# Found tweet by: @cathy_zane
# 822
#
#
# Found tweet by: @scarlet123x
# 823
#
#
# Found tweet by: @lalalaurennn___
# 824
#
#
# Found tweet by: @straighttech
# 825
#
#
# Found tweet by: @Cp_Turner_Auth
# 826
#
#
# Found tweet by: @roblwilson
# 827
#
#
# Found tweet by: @JKOB311
# 828
#
#
# Found tweet by: @SipsnScroll
# 829
#
#
# Found tweet by: @EvaContis
# 830
#
#
# Found tweet by: @keyes_helen
# 831
#
#
# Found tweet by: @neil_neilzone
# 832
#
#
# Found tweet by: @idilika
# 833
#
#
# Found tweet by: @VMSwiderski
# 834
#
#
# Found tweet by: @karl_F33
# 835
#
#
# Found tweet by: @LauraBQuigley
# 836
#
#
# Found tweet by: @Jycroispasdutou
# 837
#
#
# Found tweet by: @WkndGirl
# 838
#
#
# Found tweet by: @b_butcher15
# 839
#
#
# Found tweet by: @knownforms
# 840
#
#
# Found tweet by: @odetoslotown
# 841
#
#
# Found tweet by: @Ohshesahotmess
# 842
#
#
# Found tweet by: @kitkat232455
# 843
#
#
# Found tweet by: @BalestraAdele
# 844
#
#
# Found tweet by: @olsenkim10
# 845
#
#
# Found tweet by: @alison_gowans
# 846
#
#
# Found tweet by: @Tatib16
# 847
#
#
# Found tweet by: @mktgmike
# 848
#
#
# Found tweet by: @rapillolaw
# 849
#
#
# Found tweet by: @JaneMay220
# 850
#
#
# Found tweet by: @emphatic_tweets
# 851
#
#
# Found tweet by: @sevenofnan
# 852
#
#
# Found tweet by: @TntGuerrero
# 853
#
#
# Found tweet by: @_kingtherapy
# 854
#
#
# Found tweet by: @CHHolte
# 855
#
#
# Found tweet by: @mellyb
# 856
#
#
# Found tweet by: @ColinBeavan
# 857
#
#
# Found tweet by: @_kingtherapy
# 858
#
#
# Found tweet by: @rafavnt
# 859
#
#
# Found tweet by: @Lizard_PNW
# 860
#
#
# Found tweet by: @_kingtherapy
# 861
#
#
# Found tweet by: @MulticuentaMr
# 862
#
#
# Found tweet by: @YNOTdotcom
# 863
#
#
# Found tweet by: @JGordonBrownPM
# 864
#
#
# Found tweet by: @Essergy
# 865
#
#
# Found tweet by: @katarmstrong1
# 866
#
#
# Found tweet by: @lucy1967
# 867
#
#
# Found tweet by: @SuffolkCAC
# 868
#
#
# Found tweet by: @IndyForTheGuy
# 869
#
#
# Found tweet by: @kataisa
# 870
#
#
# Found tweet by: @forlookin
# 871
#
#
# Found tweet by: @20RubyGraham20
# 872
#
#
# Found tweet by: @ualbanyodyssey
# 873
#
#
# Found tweet by: @jvince
# 874
#
#
# Found tweet by: @nicolemaltomare
# 875
#
#
# Found tweet by: @Caplea44
# 876
#
#
# Found tweet by: @Seabaugh_Alex
# 877
#
#
# Found tweet by: @ZootopiaCity
# 878
#
#
# Found tweet by: @SadWhaleFamily
# 879
#
#
# Found tweet by: @Oh_FakeMeToday
# 880
#
#
# Found tweet by: @noahkagan
# 881
#
#
# Found tweet by: @Geepstar
# 882
#
#
# Found tweet by: @dailyTrndsttr
# 883
#
#
# Found tweet by: @MillerRachelD
# 884
#
#
# Found tweet by: @schoolinlifepod
# 885
#
#
# Found tweet by: @DY1837
# 886
#
#
# Found tweet by: @jrivera1374
# 887
#
#
# Found tweet by: @anisurrahman198
# 888
#
#
# Found tweet by: @ThaniaAB
# 889
#
#
# Found tweet by: @BM_Bourguignon
# 890
#
#
# Found tweet by: @RhondaJFlanagan
# 891
#
#
# Found tweet by: @thebeaconwkly
# 892
#
#
# Found tweet by: @APSCUF
# 893
#
#
# Found tweet by: @NorthCAliving
# 894
#
#
# Found tweet by: @emerging56
# 895
#
#
# Found tweet by: @iambrig
# 896
#
#
# Found tweet by: @Americonic
# 897
#
#
# Found tweet by: @drdcpmd
# 898
#
#
# Found tweet by: @ironyiet
# 899
#
#
# Found tweet by: @fightinjustic33
# 900
#
#
# Found tweet by: @joeybrandt1
# 901
#
#
# Found tweet by: @JosefKamu
# 902
#
#
# Found tweet by: @616Carrie
# 903
#
#
# Found tweet by: @sherrysaevil
# 904
#
#
# Found tweet by: @SweaterGrrrl
# 905
#
#
# Found tweet by: @SteveMepham
# 906
#
#
# Found tweet by: @FemMagKPFK
# 907
#
#
# Found tweet by: @NYConCon2019
# 908
#
#
# Found tweet by: @namastevibes_
# 909
#
#
# Found tweet by: @joshlawrence634
# 910
#
#
# Found tweet by: @notmyname02
# 911
#
#
# Found tweet by: @NaeNaeNx
# 912
#
#
# Found tweet by: @SwanSisters
# 913
#
#
# Found tweet by: @vievararosel
# 914
#
#
# Found tweet by: @PaturVase
# 915
#
#
# Found tweet by: @truegirl81
# 916
#
#
# Found tweet by: @quelizinha
# 917
#
#
# Found tweet by: @thesingleswan
# 918
#
#
# Found tweet by: @osato_edosa
# 919
#
#
# Found tweet by: @queenbprods
# 920
#
#
# Found tweet by: @JocelyneFox
# 921
#
#
# Found tweet by: @markburgerenerg
# 922
#
#
# Found tweet by: @cxsmiclover
# 923
#
#
# Found tweet by: @jordslice11
# 924
#
#
# Found tweet by: @eigensinn83
# 925
#
#
# Found tweet by: @digitalspywwe
# 926
#
#
# Found tweet by: @FeministCrush
# 927
#
#
# Found tweet by: @PeterB00s
# 928
#
#
# Found tweet by: @cmbatesole
# 929
#
#
# Found tweet by: @rgibli
# 930
#
#
# Found tweet by: @dammitjean
# 931
#
#
# Found tweet by: @EVAWuk
# 932
#
#
# Found tweet by: @laauren14
# 933
#
#
# Found tweet by: @pestoquiche80s
# 934
#
#
# Found tweet by: @YasmineBouchene
# 935
#
#
# Found tweet by: @JaneMay220
# 936
#
#
# Found tweet by: @clevelandrcc
# 937
#
#
# Found tweet by: @letat_lechat
# 938
#
#
# Found tweet by: @BriWedge1
# 939
#
#
# Found tweet by: @ThatOtakuGuy_
# 940
#
#
# Found tweet by: @safety_in_speed
# 941
#
#
# Found tweet by: @Castaa
# 942
#
#
# Found tweet by: @icycleivote
# 943
#
#
# Found tweet by: @lillyquintana7
# 944
#
#
# Found tweet by: @Cornelius6th
# 945
#
#
# Found tweet by: @DVBurdenofProof
# 946
#
#
# Found tweet by: @tesimmons74
# 947
#
#
# Found tweet by: @zoidonna
# 948
#
#
# Found tweet by: @PeterStoughton1
# 949
#
#
# Found tweet by: @LosVegasRocks
# 950
#
#
# Found tweet by: @janegruppalli
# 951
#
#
# Found tweet by: @clovertouchaus
# 952
#
#
# Found tweet by: @PROJECT_RWRS
# 953
#
#
# Found tweet by: @MirWriter
# 954
#
#
# Found tweet by: @IreneMossa
# 955
#
#
# Found tweet by: @FoolsGym
# 956
#
#
# Found tweet by: @quelizinha
# 957
#
#
# Found tweet by: @mfmcgrath
# 958
#
#
# Found tweet by: @lunastarlynn
# 959
#
#
# Found tweet by: @LauraManville1
# 960
# Found tweet by: @badmazel
# 961
#
#
# Found tweet by: @jasmineegross
# 962
#
#
# Found tweet by: @truegirl81
# 963
#
#
# Found tweet by: @An0nKn0wledge
# 964
#
#
# Found tweet by: @conormooreLD
# 965
#
#
# Found tweet by: @EzraFitz_13
# 966
#
#
# Found tweet by: @arycorty115
# 967
#
#
# Found tweet by: @bknight53
# 968
#
#
# Found tweet by: @Dr_RJByrne
# 969
#
#
# Found tweet by: @maba_co
# 970
#
#
# Found tweet by: @truegirl81
# 971
#
#
# Found tweet by: @mizhumanities
# 972
#
#
# Found tweet by: @TrumpChan00
# 973
#
#
# Found tweet by: @CourtneySwans20
# 974
#
#
# Found tweet by: @coulidepinla
# 975
#
#
# Found tweet by: @MentalHunnie
# 976
#
#
# Found tweet by: @KasperRudstedt
# 977
#
#
# Found tweet by: @gonsalvesxo
# 978
#
#
# Found tweet by: @soundslikeohyes
# 979
#
#
# Found tweet by: @ThatOtakuGuy_
# 980
#
#
# Found tweet by: @spaghetti_big
# 981
#
#
# Found tweet by: @Ggrimaldo123
# 982
#
#
# Found tweet by: @ThatOtakuGuy_
# 983
#
#
# Found tweet by: @Chilhon2016Lap
# 984
#
#
# Found tweet by: @EVAWuk
# 985
#
#
# Found tweet by: @pennyb
# 986
#
#
# Found tweet by: @FRANK_J_MILES
# 987
#
#
# Found tweet by: @quelizinha
# 988
#
#
# Found tweet by: @MrIanHitchings
# 989
#
#
# Found tweet by: @gonsalvesxo
# 990
#
#
# Found tweet by: @graffititracer_
# 991
#
#
# Found tweet by: @WhiteBoy41
# 992
#
#
# Found tweet by: @UtahSaint
# 993
#
#
# Found tweet by: @truegirl81
# 994
#
#
# Found tweet by: @MachineSqarrs
# 995
#
#
# Found tweet by: @FlemingCarrie
# 996
#
#
# Found tweet by: @SandraTrappen
# 997
#
#
# Found tweet by: @JenniferEdlund
# 998
#
#
# Found tweet by: @outward_rant
# 999
#
#
# Found tweet by: @womensfunding
# 1000
#
#
# Found tweet by: @abbylions04
# 1001
#
#
# Found tweet by: @ErikaMichaels4
# 1002
#
#
# Found tweet by: @linbzzz
# 1003
#
#
# Found tweet by: @FelixFelix7070
# 1004
#
#
# Found tweet by: @ronmarshaw
# 1005
#
#
# Found tweet by: @Helenhs
# 1006
#
#
# Found tweet by: @spaghetti_big
# 1007
#
#
# Found tweet by: @DVBurdenofProof
# 1008
#
#
# Found tweet by: @_Bill_Park
# 1009
#
#
# Found tweet by: @gonsalvesxo
# 1010
#
#
# Found tweet by: @godNae
# 1011
#
#
# Found tweet by: @mamaa_be
# 1012
#
#
# Found tweet by: @ThatAloraGirl
# 1013
#
#
# Found tweet by: @abbyproha
# 1014
#
#
# Found tweet by: @politicoperv
# 1015
#
#
# Found tweet by: @m_sherrington
# 1016
#
#
# Found tweet by: @MirWriter
# 1017
#
#
# Found tweet by: @SusannaReece
# 1018
#
#
# Found tweet by: @VikkiVeach1
# 1019
#
#
# Found tweet by: @EKrijtenburg
# 1020
#
#
# Found tweet by: @matildagibson98
# 1021
#
#
# Found tweet by: @truegirl81
# 1022
#
#
# Found tweet by: @LaurelAshland
# 1023
#
#
# Found tweet by: @allan_crawshaw
# 1024
#
#
# Found tweet by: @SusannaReece
# 1025
#
#
# Found tweet by: @SunGodMan1
# 1026
#
#
# Found tweet by: @no1fatherfucker
# 1027
#
#
# Found tweet by: @Olivia_kelley44
# 1028
#
#
# Found tweet by: @intelligentlyfe
# 1029
#
#
# Found tweet by: @MissBilious
# 1030
#
#
# Found tweet by: @ShireenQudosi
# 1031
#
#
# Found tweet by: @DigiRanger1994
# 1032
#
#
# Found tweet by: @HelaoSilas
# 1033
#
#
# Found tweet by: @JuliaTilden
# 1034
#
#
# Found tweet by: @BumblingBombus
# 1035
#
#
# Found tweet by: @stedsimple
# 1036
#
#
# Found tweet by: @Landorcan
# 1037
#
#
# Found tweet by: @MacGruber
# 1038
#
#
# Found tweet by: @gonsalvesxo
# 1039
#
#
# Found tweet by: @TreatyNotifier
# 1040
#
#
# Found tweet by: @RemingtonWild
# 1041
#
#
# Found tweet by: @babygatorswamp
# 1042
#
#
# Found tweet by: @suestroud
# 1043
#
#
# Found tweet by: @sgtmolly06
# 1044
#
#
# Found tweet by: @vlamarca
# 1045
#
#
# Found tweet by: @bjhutch
# 1046
#
#
# Found tweet by: @trycshealing
# 1047
#
#
# Found tweet by: @nicole_simes
# 1048
#
#
# Found tweet by: @ShellyLazoff
# 1049
#
#
# Found tweet by: @HelenWilson36
# 1050
#
#
# Found tweet by: @geejayeff
# 1051
#
#
# Found tweet by: @kitesurfpastor
# 1052
#
#
# Found tweet by: @wagesofwins
# 1053
#
#
# Found tweet by: @LalaMusings
# 1054
#
#
# Found tweet by: @JennaPrice
# 1055
#
#
# Found tweet by: @qas85
# 1056
#
#
# Found tweet by: @annemsia
# 1057
#
#
# Found tweet by: @daysparrow
# 1058
#
#
# Found tweet by: @vincetographer
# 1059
#
#
# Found tweet by: @vengance999
# 1060
#
#
# Found tweet by: @DStahrr8
# 1061
#
#
# Found tweet by: @swell
# 1062
#
#
# Found tweet by: @abbeykakes
# 1063
#
#
# Found tweet by: @ManifestingKey
# 1064
#
#
# Found tweet by: @letat_lechat
# 1065
#
#
# Found tweet by: @HelenLOrange2
# 1066
#
#
# Found tweet by: @weinhere4
# 1067
#
#
# Found tweet by: @laurenrajczak
# 1068
#
#
# Found tweet by: @TMBListener
# 1069
#
#
# Found tweet by: @AskWithoutShame
# 1070
#
#
# Found tweet by: @poorbabyboomer
# 1071
#
#
# Found tweet by: @CapTimes
# 1072
#
#
# Found tweet by: @ariadne_syd
# 1073
#
#
# Found tweet by: @megan_nobert
# 1074
#
#
# Found tweet by: @MathildevVliet
# 1075
#
#
# Found tweet by: @MoneyTrain
# 1076
#
#
# Found tweet by: @hispanicgaljaz
# 1077
#
#
# Found tweet by: @viewfromthecave
# 1078
#
#
# Found tweet by: @CeciliaNano
# 1079
#
#
# Found tweet by: @caseycochrane
# 1080
#
#
# Found tweet by: @16daysgoneviral
# 1081
#
#
# Found tweet by: @WakingUpFrank
# 1082
#
#
# Found tweet by: @PeterCrumpler
# 1083
#
#
# Found tweet by: @Donnn__
# 1084
#
#
# Found tweet by: @eb12099
# 1085
#
#
# Found tweet by: @nigel2john
# 1086
#
#
# Found tweet by: @DCO_6
# 1087
#
#
# Found tweet by: @HelenLOrange2
# 1088
#
#
# Found tweet by: @beepea
# 1089
#
#
# Found tweet by: @BroadAgenda5050
# 1090
#
#
# Found tweet by: @CherylBond20
# 1091
#
#
# Found tweet by: @AlaskaSnob
# 1092
#
#
# Found tweet by: @lynnhb
# 1093
#
#
# Found tweet by: @TomLindseyNDP
# 1094
#
#
# Found tweet by: @BUBYSGIRL
# 1095
#
#
# Found tweet by: @AStudentsJourn1
# 1096
#
#
# Found tweet by: @StLeonards2016
# 1097
#
#
# Found tweet by: @VivienneHowl
# 1098
#
#
# Found tweet by: @BroadAgenda5050
# 1099
#
#
# Found tweet by: @FortKnott
# 1100
#
#
# Found tweet by: @filmfatalesTO
# 1101
#
#
# Found tweet by: @32flavoursNudi
# 1102
#
#
# Found tweet by: @BreeAnnFausett
# 1103
#
#
# Found tweet by: @Carlfletcher15
# 1104
#
#
# Found tweet by: @kellywynne23
# 1105
#
#
# Found tweet by: @NARALMissouri
# 1106
#
#
# Found tweet by: @NatashaRolls1
# 1107
#
#
# Found tweet by: @hollywinterburn
# 1108
#
#
# Found tweet by: @USANEWS_
# 1109
#
#
# Found tweet by: @WeeklyNewsToday
# 1110
#
#
# Found tweet by: @ivanamassetti
# 1111
#
#
# Found tweet by: @MichelleBeale17
# 1112
#
#
# Found tweet by: @MyNewsLA
# 1113
#
#
# Found tweet by: @EuroCelt
# 1114
#
#
# Found tweet by: @Virginia_Hauss
# 1115
#
#
# Found tweet by: @artemisprime
# 1116
#
#
# Found tweet by: @CamillaEClarke
# 1117
#
#
# Found tweet by: @RLTW609
# 1118
#
#
# Found tweet by: @MichelleBeale17
# 1119
#
#
# Found tweet by: @happier_better
# 1120
#
#
# Found tweet by: @cate_gee
# 1121
#
#
# Found tweet by: @ExpressionTees
# 1122
#
#
# Found tweet by: @DIGITALDECODED1
# 1123
#
#
# Found tweet by: @TCHCollins
# 1124
#
#
# Found tweet by: @ClearlyQueerly
# 1125
#
#
# Found tweet by: @Nihad_Nour
# 1126
#
#
# Found tweet by: @franksan240
# 1127
#
#
# Found tweet by: @SobeitKhan
# 1128
#
#
# Found tweet by: @ArthurCSchaper
# 1129
#
#
# Found tweet by: @June15again
# 1130
#
#
# Found tweet by: @lerrod
# 1131
#
#
# Found tweet by: @denizasuu
# 1132
#
#
# Found tweet by: @SandyLCYoung
# 1133
#
#
# Found tweet by: @Anarres_moonelf
# 1134
#
#
# Found tweet by: @Emmacochrane9
# 1135
#
#
# Found tweet by: @dukefanshan
# 1136
#
#
# Found tweet by: @Ohshesahotmess
# 1137
#
#
# Found tweet by: @ADHD4Life72
# 1138
#
#
# Found tweet by: @cmccr
# 1139
#
#
# Found tweet by: @naturalgashi
# 1140
#
#
# Found tweet by: @NekoOlives14
# 1141
#
#
# Found tweet by: @jimallthetime
# 1142
#
#
# Found tweet by: @MaryHorodyski
# 1143
#
#
# Found tweet by: @lawdotcom
# 1144
#
#
# Found tweet by: @dare2misbehave
# 1145
#
#
# Found tweet by: @matttrueman
# 1146
#
#
# Found tweet by: @1SweetQ
# 1147
#
#
# Found tweet by: @cbvet420
# 1148
#
#
# Found tweet by: @brianneamira
# 1149
#
#
# Found tweet by: @ndpcaucus
# 1150
#
#
# Found tweet by: @chocolatehound
# 1151
#
#
# Found tweet by: @BlufPurdi
# 1152
#
#
# Found tweet by: @KittyLeeSC
# 1153
#
#
# Found tweet by: @rslsuwanee
# 1154
#
#
# Found tweet by: @ArlingtonCoB
# 1155
#
#
# Found tweet by: @ClipTrends
# 1156
#
#
# Found tweet by: @feliciaw5853
# 1157
#
#
# Found tweet by: @AsexualJournal
# 1158
#
#
# Found tweet by: @SchoolmarmDE
# 1159
#
#
# Found tweet by: @marvel467
# 1160
#
#
# Found tweet by: @TaureanReign
# 1161
#
#
# Found tweet by: @PS641600
# 1162
#
#
# Found tweet by: @BrittainDC
# 1163
#
#
# Found tweet by: @cori_marshall15
# 1164
#
#
# Found tweet by: @hetroman69
# 1165
#
#
# Found tweet by: @Dee_623
# 1166
#
#
# Found tweet by: @BehaveWellness
# 1167
#
#
# Found tweet by: @2tuff15
# 1168
#
#
# Found tweet by: @susiebabiee
# 1169
#
#
# Found tweet by: @EllevateFairWes
# 1170
#
#
# Found tweet by: @ClearMindedness
# 1171
#
#
# Found tweet by: @susanmc15104271
# 1172
#
#
# Found tweet by: @sallycroachy
# 1173
#
#
# Found tweet by: @christysturm
# 1174
#
#
# Found tweet by: @Virginia_Hauss
# 1175
#
#
# Found tweet by: @Holly500
# 1176
#
#
# Found tweet by: @Eloc42617770
# 1177
#
#
# Found tweet by: @MakingTownsGuy
# 1178
#
#
# Found tweet by: @QueerBillie
# 1179
#
#
# Found tweet by: @AdHealthCenter
# 1180
#
#
# Found tweet by: @TheOggOne
# 1181
#
#
# Found tweet by: @fathermag
# 1182
#
#
# Found tweet by: @Direct7E
# 1183
#
#
# Found tweet by: @THEMUSEUM
# 1184
#
#
# Found tweet by: @Gregory_Malchuk
# 1185
#
#
# Found tweet by: @MrLarwood
# 1186
#
#
# Found tweet by: @Glambert40291
# 1187
#
#
# Found tweet by: @AIAusa
# 1188
#
#
# Found tweet by: @masbutter
# 1189
#
#
# Found tweet by: @crystalssfea
# 1190
#
#
# Found tweet by: @GTMINCsfl
# 1191
#
#
# Found tweet by: @PeterStoughton1
# 1192
#
#
# Found tweet by: @Upstairs2dRight
# 1193
#
#
# Found tweet by: @AtBestIsKorny
# 1194
#
#
# Found tweet by: @ambsclark
# 1195
#
#
# Found tweet by: @PaulaSayles
# 1196
#
#
# Found tweet by: @moosajee_dhorat
# 1197
#
#
# Found tweet by: @aperl18
# 1198
#
#
# Found tweet by: @msnomir
# 1199
#
#
# Found tweet by: @TheJeremyPaul
# 1200
# Found tweet by: @Mariyah_Israel
# 1201
#
#
# Found tweet by: @hetroman69
# 1202
#
#
# Found tweet by: @Fred__Englander
# 1203
#
#
# Found tweet by: @MrIanHitchings
# 1204
#
#
# Found tweet by: @WaywardWinifred
# 1205
#
#
# Found tweet by: @ConnieinBonnie
# 1206
#
#
# Found tweet by: @hlpryor
# 1207
#
#
# Found tweet by: @efemmera
# 1208
#
#
# Found tweet by: @emc137
# 1209
#
#
# Found tweet by: @mothermade
# 1210
#
#
# Found tweet by: @Darkness2Light
# 1211
#
#
# Found tweet by: @_thislineismine
# 1212
#
#
# Found tweet by: @montrealinform
# 1213
#
#
# Found tweet by: @morningly_
# 1214
#
#
# Found tweet by: @LarryBureau
# 1215
#
#
# Found tweet by: @KoriFerris
# 1216
#
#
# Found tweet by: @addcount
# 1217
#
#
# Found tweet by: @milksokUK
# 1218
#
#
# Found tweet by: @dotcomlandlords
# 1219
#
#
# Found tweet by: @kuntsuragi
# 1220
#
#
# Found tweet by: @mikerestorer
# 1221
#
#
# Found tweet by: @Andrea_WVI
# 1222
#
#
# Found tweet by: @need_history
# 1223
#
#
# Found tweet by: @choonheechae
# 1224
#
#
# Found tweet by: @ProMediaRes1
# 1225
#
#
# Found tweet by: @neilsimmons63
# 1226
#
#
# Found tweet by: @ChiFdn4Women
# 1227
#
#
# Found tweet by: @JPhillipsVT
# 1228
#
#
# Found tweet by: @ThatVDOVault
# 1229
#
#
# Found tweet by: @spectrummag
# 1230
#
#
# Found tweet by: @IncredibleJessi
# 1231
#
#
# Found tweet by: @EducatingCole
# 1232
#
#
# Found tweet by: @grapegrills
# 1233
#
#
# Found tweet by: @dotcomlandlords
# 1234
#
#
# Found tweet by: @ronakshah
# 1235
#
#
# Found tweet by: @GRoccanova
# 1236
#
#
# Found tweet by: @RhondaJFlanagan
# 1237
#
#
# Found tweet by: @nann_brown
# 1238
#
#
# Found tweet by: @sarahmontei13
# 1239
#
#
# Found tweet by: @Aprinc3ss88
# 1240
#
#
# Found tweet by: @a2z_social
# 1241
#
#
# Found tweet by: @ImChelseaGreen
# 1242
#
#
# Found tweet by: @brandyyhowe_
# 1243
#
#
# Found tweet by: @ThatVDOVault
# 1244
#
#
# Found tweet by: @CeciliaNano
# 1245
#
#
# Found tweet by: @yesmagazine
# 1246
#
#
# Found tweet by: @ninaburleigh
# 1247
#
#
# Found tweet by: @CarolynShimmin
# 1248
#
#
# Found tweet by: @EvanMMinton
# 1249
#
#
# Found tweet by: @ThatVDOVault
# 1250
#
#
# Found tweet by: @ScottChampion9
# 1251
#
#
# Found tweet by: @joglasg
# 1252
#
#
# Found tweet by: @DaniHays5
# 1253
#
#
# Found tweet by: @CMEintheRockies
# 1254
#
#
# Found tweet by: @WomensMarchHOU
# 1255
#
#
# Found tweet by: @BastnEva
# 1256
#
#
# Found tweet by: @Rrabbit86961548
# 1257
#
#
# Found tweet by: @IDzine01
# 1258
#
#
# Found tweet by: @f990b291c0244a0
# 1259
#
#
# Found tweet by: @ArielBlocker
# 1260
#
#
# Found tweet by: @RichardLNeal
# 1261
#
#
# Found tweet by: @UWCampus
# 1262
#
#
# Found tweet by: @UniteWomenOrg
# 1263
#
#
# Found tweet by: @catfever83
# 1264
#
#
# Found tweet by: @kris_krow
# 1265
#
#
# Found tweet by: @DebiJules
# 1266
#
#
# Found tweet by: @chynaanyhc
# 1267
#
#
# Found tweet by: @NabokovBlue
# 1268
#
#
# Found tweet by: @emilyrosecena
# 1269
#
#
# Found tweet by: @ZivaMeditation
# 1270
#
#
# Found tweet by: @ktxtensen
# 1271
#
#
# Found tweet by: @ThatAnitaLive
# 1272
#
#
# Found tweet by: @Henry_TheSavage
# 1273
#
#
# Found tweet by: @MarkiaLorena
# 1274
#
#
# Found tweet by: @Lame_name_tweet
# 1275
#
#
# Found tweet by: @Fred__Englander
# 1276
#
#
# Found tweet by: @NahanniFontaine
# 1277
#
#
# Found tweet by: @Sheville
# 1278
#
#
# Found tweet by: @pettersjoblom
# 1279
#
#
# Found tweet by: @ALT_Views
# 1280
#
#
# Found tweet by: @mightyming52
# 1281
#
#
# Found tweet by: @bhandari_sid
# 1282
#
#
# Found tweet by: @RippersZipper
# 1283
#
#
# Found tweet by: @WiscoPost
# 1284
#
#
# Found tweet by: @RobinReichelt1
# 1285
#
#
# Found tweet by: @TheREALISTERR
# 1286
#
#
# Found tweet by: @bea1060
# 1287
#
#
# Found tweet by: @lordspencer
# 1288
#
#
# Found tweet by: @billcoops
# 1289
#
#
# Found tweet by: @MrIanHitchings
# 1290
#
#
# Found tweet by: @twagc1
# 1291
#
#
# Found tweet by: @DramaGirl42
# 1292
#
#
# Found tweet by: @leicspolice
# 1293
#
#
# Found tweet by: @CatSharkSherpa
# 1294
#
#
# Found tweet by: @WeworkCocainee
# 1295
#
#
# Found tweet by: @Vocab_BGP
# 1296
#
#
# Found tweet by: @RandlePMcMurphe
# 1297
#
#
# Found tweet by: @JazBenz
# 1298
#
#
# Found tweet by: @TheRoxyWarPaint
# 1299
#
#
# Found tweet by: @NeckBone305
# 1300
#
#
# Found tweet by: @stevenomadusa
# 1301
#
#
# Found tweet by: @wezlangdon
# 1302
#
#
# Found tweet by: @DonNohVarr
# 1303
#
#
# Found tweet by: @UniteWomenCO
# 1304
#
#
# Found tweet by: @joglasg
# 1305
#
#
# Found tweet by: @MHBoys
# 1306
#
#
# Found tweet by: @HeForShe
# 1307
#
#
# Found tweet by: @DarrenP24191399
# 1308
#
#
# Found tweet by: @beingdealtwit
# 1309
#
#
# Found tweet by: @50somethings
# 1310
#
#
# Found tweet by: @DayaHouston
# 1311
#
#
# Found tweet by: @ASTRAYouth
# 1312
#
#
# Found tweet by: @Stacey4UHoos
# 1313
#
#
# Found tweet by: @AStudentsJourn1
# 1314
#
#
# Found tweet by: @CathyCathyFox
# 1315
#
#
# Found tweet by: @BYWSKULL
# 1316
#
#
# Found tweet by: @ThatVDOVault
# 1317
#
#
# Found tweet by: @Emma_Brunny
# 1318
#
#
# Found tweet by: @Shazzalive
# 1319
#
#
# Found tweet by: @TaylorSJ90
# 1320
#
#
# Found tweet by: @Pal2Badgers
# 1321
#
#
# Found tweet by: @MommyNooz
# 1322
#
#
# Found tweet by: @anderson_hoops
# 1323
#
#
# Found tweet by: @deborahallen77
# 1324
#
#
# Found tweet by: @Thebfromtuam
# 1325
#
#
# Found tweet by: @seru25
# 1326
#
#
# Found tweet by: @dvoyhalt
# 1327
#
#
# Found tweet by: @liannetic
# 1328
#
#
# Found tweet by: @jakethemoonson
# 1329
#
#
# Found tweet by: @kristantmoser
# 1330
#
#
# Found tweet by: @FunInMia
# 1331
#
#
# Found tweet by: @EJLandwehr
# 1332
#
#
# Found tweet by: @JJArbogast
# 1333
#
#
# Found tweet by: @BrittnyMcCarthy
# 1334
#
#
# Found tweet by: @Auroraknite
# 1335
#
#
# Found tweet by: @spidercircus
# 1336
#
#
# Found tweet by: @DrBruceScott
# 1337
#
#
# Found tweet by: @TVlogosSuck
# 1338
#
#
# Found tweet by: @SFBEX
# 1339
#
#
# Found tweet by: @HelenWilson36
# 1340
#
#
# Found tweet by: @scarlet123x
# 1341
#
#
# Found tweet by: @SFBEX
# 1342
#
#
# Found tweet by: @edossmanlpc
# 1343
#
#
# Found tweet by: @jt2blackcab
# 1344
#
#
# Found tweet by: @gcsunrise
# 1345
#
#
# Found tweet by: @waitgodot
# 1346
#
#
# Found tweet by: @toxicreject1
# 1347
#
#
# Found tweet by: @petepetersen66
# 1348
#
#
# Found tweet by: @BlueSea1964
# 1349
#
#
# Found tweet by: @Andre_Isawolf
# 1350
#
#
# Found tweet by: @AndreMelissa9
# 1351
#
#
# Found tweet by: @HofCulCtr
# 1352
#
#
# Found tweet by: @Aya_Kal
# 1353
#
#
# ...
# 2309
#
#
# Found tweet by: @ChantelleALowe
# 2310
#
#
# Found tweet by: @MKFerrante
# 2311
#
#
# Found tweet by: @MeTooMovementt
# 2312
#
#
# Found tweet by: @squat_kromera
# 2313
#
#
# Found tweet by: @nadabakos
# 2314
#
#
# Found tweet by: @kellysparky1971
# 2315
#
#
# Found tweet by: @mojovaibho
# 2316
#
#
# Found tweet by: @SpartansCare1
# 2317
#
#
# Found tweet by: @RESET_2017
# 2318
#
#
# Found tweet by: @inokohwetrust
# 2319
#
#
# Found tweet by: @sportnetcy
# 2320
#
#
# Found tweet by: @_ShaunDougherty
# 2321
#
#
# Found tweet by: @kyle_parlier7
# 2322
#
#
# Found tweet by: @PJohnMarshall
# 2323
#
#
# Found tweet by: @tweettomania
# 2324
#
#
# Found tweet by: @filmradar
# 2325
#
#
# Found tweet by: @SJHKittenBellza
# 2326
#
#
# Found tweet by: @SkiBabyIII
# 2327
#
#
# Found tweet by: @TrixieDalek
# 2328
#
#
# Found tweet by: @ThatVDOVault
# 2329
#
#
# Found tweet by: @TomPaine1737
# 2330
#
#
# Found tweet by: @ChantelleALowe
# 2331
#
#
# Found tweet by: @HerXreality
# 2332
#
#
# Found tweet by: @stopstoviolence
# 2333
#
#
# Found tweet by: @kurraaaaaaa
# 2334
#
#
# Found tweet by: @HotNewHipHop
# 2335
#
#
# Found tweet by: @lauren_feldman9
# 2336
#
#
# Found tweet by: @Sh3_Wo1f
# 2337
#
#
# Found tweet by: @BuddhaHosea
# 2338
#
#
# Found tweet by: @lisatozzi
# 2339
#
#
# Found tweet by: @georgewashing71
# 2340
#
#
# Found tweet by: @writerzena
# 2341
#
#
# Found tweet by: @Erin_Lynn94
# 2342
#
#
# Found tweet by: @ashleytgill12
# 2343
#
#
# Found tweet by: @granamoryoko18
# 2344
#
#
# Found tweet by: @CuzItsAboutTime
# 2345
#
#
# Found tweet by: @Jacquel42250856
# 2346
#
#
# Found tweet by: @maylanielyn
# 2347
#
#
# Found tweet by: @georgewashing71
# 2348
#
#
# Found tweet by: @Dad_of_5
# 2349
#
#
# Found tweet by: @RightForMight
# 2350
#
#
# Found tweet by: @695HOOPS
# 2351
#
#
# Found tweet by: @TyCraig311
# 2352
#
#
# Found tweet by: @LaraDevganMD
# 2353
#
#
# Found tweet by: @georgewashing71
# 2354
#
#
# Found tweet by: @Botched33
# 2355
#
#
# Found tweet by: @hannahmartin20_
# 2356
#
#
# Found tweet by: @smcho0311
# 2357
#
#
# Found tweet by: @georgewashing71
# 2358
#
#
# Found tweet by: @asuka_250
# 2359
#
#
# Found tweet by: @freetodate1
# 2360
#
#
# Found tweet by: @asuka_250
# 2361
#
#
# Found tweet by: @georgewashing71
# 2362
#
#
# Found tweet by: @filhanfitri
# 2363
#
#
# Found tweet by: @KevinCahill22
# 2364
#
#
# Found tweet by: @MianZain97
# 2365
#
#
# Found tweet by: @Marileee_013114
# 2366
#
#
# Found tweet by: @DailyContessa
# 2367
#
#
# Found tweet by: @georgewashing71
# 2368
#
#
# Found tweet by: @elemcie_me
# 2369
#
#
# Found tweet by: @IAMOHIONURSE
# 2370
#
#
# Found tweet by: @georgewashing71
# 2371
#
#
# Found tweet by: @americanempire
# 2372
#
#
# Found tweet by: @lifeofaHooper_
# 2373
#
#
# Found tweet by: @MoNkEyReSisTs
# 2374
#
#
# Found tweet by: @siyandavitshima
# 2375
#
#
# Found tweet by: @Jacquel42250856
# 2376
#
#
# Found tweet by: @georgewashing71
# 2377
#
#
# Found tweet by: @papacandelaria
# 2378
#
#
# Found tweet by: @tannishg
# 2379
#
#
# Found tweet by: @TwistedBraid_
# 2380
#
#
# Found tweet by: @MeTooMovementt
# 2381
#
#
# Found tweet by: @LoraleiVB
# 2382
#
#
# Found tweet by: @danscott1999
# 2383
#
#
# Found tweet by: @ACM_workingmom
# 2384
#
#
# Found tweet by: @sudocrushms
# 2385
#
#
# Found tweet by: @katiedigc
# 2386
#
#
# Found tweet by: @writingbikes
# 2387
#
#
# Found tweet by: @Carolyn00287950
# 2388
#
#
# Found tweet by: @texgretch
# 2389
#
#
# Found tweet by: @papacandelaria
# 2390
#
#
# Found tweet by: @Sereneami
# 2391
#
#
# Found tweet by: @niksthompson
# 2392
#
#
# Found tweet by: @LaylaJWest
# 2393
#
#
# Found tweet by: @Jacquel42250856
# 2394
#
#
# Found tweet by: @ManuelaRiosB
# 2395
#
#
# Found tweet by: @EndDeportations
# 2396
#
#
# Found tweet by: @DIGITALDECODED1
# 2397
#
#
# Found tweet by: @LovingSanders
# 2398
#
#
# Found tweet by: @cin_rogers
# 2399
#
#
# Found tweet by: @jkm_563
# 2400
#
#
# Found tweet by: @Mtbkgrl
# 2401
#
#
# Found tweet by: @katewallistweet
# 2402
#
#
# Found tweet by: @NwaRisimat
# 2403
#
#
# Found tweet by: @_ShaunDougherty
# 2404
#
#
# Found tweet by: @lily_hample
# 2405
#
#
# Found tweet by: @znipsel
# 2406
#
#
# Found tweet by: @Zkorpiozz
# 2407
#
#
# Found tweet by: @SteelCityGator
# 2408
#
#
# Found tweet by: @Galileo_35
# 2409
#
#
# Found tweet by: @ivanamassetti
# 2410
#
#
# Found tweet by: @Bshooters
# 2411
#
#
# Found tweet by: @gbib20
# 2412
#
#
# Found tweet by: @tcapp_
# 2413
#
#
# Found tweet by: @brittany_mac_
# 2414
#
#
# Found tweet by: @BirkelandLana
# 2415
#
#
# Found tweet by: @kimtairi
# 2416
#
#
# Found tweet by: @MoritzEsther
# 2417
#
#
# Found tweet by: @JoPirroneLaw
# 2418
#
#
# Found tweet by: @creasetoefurr
# 2419
#
#
# Found tweet by: @bossalikenova
# 2420
#
#
# Found tweet by: @dianapfrancis
# 2421
#
#
# Found tweet by: @RrrussT1
# 2422
#
#
# Found tweet by: @hammondcarson10
# 2423
#
#
# Found tweet by: @LegitneyHouston
# 2424
#
#
# Found tweet by: @___said
# 2425
#
#
# Found tweet by: @steeeve002
# 2426
#
#
# Found tweet by: @neia_the_libra
# 2427
#
#
# Found tweet by: @marianajfe
# 2428
#
#
# Found tweet by: @satirist_indian
# 2429
#
#
# Found tweet by: @bopzybee
# 2430
#
#
# Found tweet by: @caitlinmeroney
# 2431
#
#
# Found tweet by: @hijinksandhalos
# 2432
#
#
# Found tweet by: @TwoGloveLefty13
# 2433
#
#
# Found tweet by: @DeannaMccarvell
# 2434
#
#
# Found tweet by: @rgcainmd
# 2435
#
#
# Found tweet by: @gregmroscoe
# 2436
#
#
# Found tweet by: @CanadiensFan
# 2437
#
#
# Found tweet by: @lenubienne
# 2438
#
#
# Found tweet by: @RAnneShirley
# 2439
#
#
# Found tweet by: @JanineBliss
# 2440
#
#
# Found tweet by: @stunnatiff
# 2441
#
#
# Found tweet by: @michaelwandrade
# 2442
#
#
# Found tweet by: @gingerkelly77
# 2443
#
#
# Found tweet by: @SocialChangeAus
# 2444
#
#
# Found tweet by: @TheMeccanism
# 2445
#
#
# Found tweet by: @MSageGustafson
# 2446
#
#
# Found tweet by: @kayelljohn
# 2447
#
#
# Found tweet by: @divakleo
# 2448
#
#
# Found tweet by: @shelbyleopold09
# 2449
#
#
# Found tweet by: @letat_lechat
# 2450
#
#
# Found tweet by: @TawaSpirit
# 2451
#
#
# Found tweet by: @ZacharyZawazu
# 2452
#
#
# Found tweet by: @hendrix_carson
# 2453
#
#
# Found tweet by: @DavidAllenCoe88
# 2454
#
#
# Found tweet by: @tumisole
# 2455
#
#
# Found tweet by: @Vishmaya333
# 2456
#
#
# Found tweet by: @SammiSpock
# 2457
#
#
# Found tweet by: @christinesharp
# 2458
#
#
# Found tweet by: @terrijacques8
# 2459
#
#
# Found tweet by: @gbrew13
# 2460
#
#
# Found tweet by: @leah_5410
# 2461
#
#
# Found tweet by: @ajusticecause
# 2462
#
#
# Found tweet by: @JurgburyWrites
# 2463
#
#
# Found tweet by: @Jule_Brown12
# 2464
#
#
# Found tweet by: @ChulayoM
# 2465
#
#
# Found tweet by: @ivanamassetti
# 2466
#
#
# Found tweet by: @Glizzy__Montana
# 2467
#
#
# Found tweet by: @nneusj
# 2468
#
#
# Found tweet by: @Santanathetruth
# 2469
#
#
# Found tweet by: @KeiraFoSho
# 2470
#
#
# Found tweet by: @kristinkimbart
# 2471
#
#
# Found tweet by: @ea29
# 2472
#
#
# Found tweet by: @chibinyonka
# 2473
#
#
# Found tweet by: @Santanathetruth
# 2474
#
#
# Found tweet by: @busblog
# 2475
#
#
# Found tweet by: @eeball21
# 2476
#
#
# Found tweet by: @_Spxctrx
# 2477
#
#
# Found tweet by: @bigbuchan
# 2478
#
#
# Found tweet by: @TrishCanuck
# 2479
#
#
# Found tweet by: @MilanPty
# 2480
#
#
# Found tweet by: @carolinejungg
# 2481
#
#
# Found tweet by: @ilocinetweet
# 2482
#
#
# Found tweet by: @CopyOfOne
# 2483
#
#
# Found tweet by: @LarisTMillarez
# 2484
#
#
# Found tweet by: @xoSweetTweetxo
# 2485
#
#
# Found tweet by: @kristinkimbart
# 2486
#
#
# Found tweet by: @celldelaphontae
# 2487
#
#
# Found tweet by: @TekkolEmir
# 2488
#
#
# Found tweet by: @Bodhi1951
# 2489
#
#
# Found tweet by: @KARMAPYMNTPLAN
# 2490
#
#
# Found tweet by: @limanews
# 2491
#
#
# Found tweet by: @LeaseTwo
# 2492
#
#
# Found tweet by: @GeeGeeLovesJB
# 2493
#
#
# Found tweet by: @iskandarhanif1
# 2494
#
#
# Found tweet by: @ManyaZuba
# 2495
#
#
# Found tweet by: @ajusticecause
# 2496
#
#
# Found tweet by: @PeterStoughton1
# 2497
#
#
# Found tweet by: @LunaLuvgood2017
# 2498
#
#
# Found tweet by: @itzelyn_
# 2499
#
#
# Found tweet by: @ephebos
# 2500
# Too much gonna sleep!
# Okay reset!
#
#
# Found tweet by: @Jacquel42250856
# 1
#
#
# Found tweet by: @harlechnnorfolk
# 2
#
#
# Found tweet by: @funeral_homie
# 3
#
#
# Found tweet by: @Ballislife_T_
# 4
#
#
# Found tweet by: @catholicahafan
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384             try:  # Python 2.7, use buffering of HTTP responses
# --> 385                 httplib_response = conn.getresponse(buffering=True)
#     386             except TypeError:  # Python 2.6 and older
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# RemoteDisconnected                        Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386             except TypeError:  # Python 2.6 and older
# --> 387                 httplib_response = conn.getresponse()
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     402                     retries=self.max_retries,
# --> 403                     timeout=timeout
#     404                 )
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     622             retries = retries.increment(method, url, error=e, _pool=self,
# --> 623                                         _stacktrace=sys.exc_info()[2])
#     624             retries.sleep()
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     254             if read is False:
# --> 255                 raise six.reraise(type(error), error, _stacktrace)
#     256             elif read is not None:
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     308         if value.__traceback__ is not tb:
# --> 309             raise value.with_traceback(tb)
#     310         raise value
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     577                                                   body=body, headers=headers,
# --> 578                                                   chunked=chunked)
#     579
#
# /usr/local/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386             except TypeError:  # Python 2.6 and older
# --> 387                 httplib_response = conn.getresponse()
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     186                                                 auth=auth,
# --> 187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     584         # Send the request
# --> 585         r = adapter.send(request, **kwargs)
#     586
#
# /usr/local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     452         except (ProtocolError, socket.error) as err:
# --> 453             raise ConnectionError(err, request=request)
#     454
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-122-6486fdf57655> in <module>()
#       5
#       6 count_tweet = 0
# ----> 7 for tweet in tweepy.Cursor(api.search,q='#metoo',lang='en',include_entities=True).items(600000):
#       8     if not tweet.retweeted:
#       9         count_tweet += 1
#
# /usr/local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      47
#      48     def __next__(self):
# ---> 49         return self.next()
#      50
#      51     def next(self):
#
# /usr/local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     195         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     196             # Reached end of current page, get the next page...
# --> 197             self.current_page = self.page_iterator.next()
#     198             self.page_index = -1
#     199         self.page_index += 1
#
# /usr/local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     106
#     107         if self.index >= len(self.results) - 1:
# --> 108             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     109
#     110             if hasattr(self.method, '__self__'):
#
# /usr/local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     243             return method
#     244         else:
# --> 245             return method.execute()
#     246
#     247     # Set pagination mode
#
# /usr/local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     187                                                 proxies=self.api.proxy)
#     188                 except Exception as e:
# --> 189                     raise TweepError('Failed to send request: %s' % e)
#     190                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#     191                 if rem_calls is not None:
#
# TweepError: Failed to send request: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %% [markdown]
# # This snippet takes the list and creates a df and downloads it

# %%
df = pd.DataFrame(our_list)
df.drop_duplicates(subset='tweet_text', keep=False, inplace=True)
df.tweet_text = df.tweet_text.str.lower()
df.user_description = df.user_description.str.lower()
df.to_csv("results.csv", index=False)

# %% [markdown]
# # If you wanna look beyond current tweets this a second slower script I made
# The twitter API goes only 7 days back. This is to search whenever. It collects tweet ids and stores them in a json file

# %%
from bs4 import BeautifulSoup
import requests as rq

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime


# edit these three variables
user = 'balancetonporc'
start = datetime.datetime(2017, 10, 15)  # year, month, day
end = datetime.datetime(2017, 10, 25)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()


# don't mess with this stuff
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item:not(.AdaptiveStreamUserGallery)'
user = user.lower()
ids = []


def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?l=fr&q=%23'
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

           # found_tweets += next_tweets_chunk[:]

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))


        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)


try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))
except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
#driver.close()

# %%
# https://twitter.com/search?l=fr&q=%23moiaussi%20since%3A2017-11-06%20until%3A2017-11-07&src=typd
    
# https://twitter.com/search?l=fr&q=#moiaussi%20since%3A2017-11-07%20until%3A2017-11-08include%3Aretweets&src=typd

# %%
# id

# %%
# found_tweets.

# %% [markdown]
# # Now we take those ids and request the tweet jsons

# %%
import tweepy
import json
import math
import glob
import csv
import zipfile
import zlib
from tweepy import TweepError
from time import sleep

# %% [markdown]
# # BUFFER

# %%
our_list = []
user = '#metoo'

with open('api_keys.json') as f:
    keys = json.load(f)

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
auth.secure = True
api = tweepy.API(auth)

user = user.lower()

with open('all_ids.json') as f:
    ids = json.load(f)

print('total ids: {}'.format(len(ids)))

all_data = []
start = 0
end = 100
limit = len(ids)
i = math.ceil(limit / 100)

for go in range(i):
    print('currently getting {} - {}'.format(start, end))
    sleep(6)  # needed to prevent hitting API rate limit
    id_batch = ids[start:end]
    start += 100
    end += 100
    tweets = api.statuses_lookup(id_batch)
    for tweet in tweets:
        all_data.append(dict(tweet._json))

print('metadata collection complete')
# Out:
# total ids: 218
# currently getting 0 - 100
# currently getting 100 - 200
# currently getting 200 - 300
# metadata collection complete

# %%
all_data[1]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Oct 21 12:57:47 +0000 2017',
#  'entities': {'hashtags': [{'indices': [55, 68], 'text': 'mystylerocks'},
#    {'indices': [69, 86], 'text': 'tsipras_proverbs'},
#    {'indices': [87, 93], 'text': 'MeToo'},
#    {'indices': [94, 105], 'text': 'thevoiceGR'},
#    {'indices': [106, 119], 'text': 'shoppingstar'},
#    {'indices': [120, 128], 'text': 'Flicker'}],
#   'symbols': [],
#   'urls': [{'display_url': "olympicmarketingsystem.com/it'stimeincome…",
#     'expanded_url': "https://olympicmarketingsystem.com/it'stimeincomesal",
#     'indices': [31, 54],
#     'url': 'https://t.co/gV9q1nUzHF'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 921722179540090881,
#  'id_str': '921722179540090881',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'el',
#  'place': {'attributes': {},
#   'bounding_box': {'coordinates': [[[22.8905274, 35.8224754],
#      [24.1165237, 35.8224754],
#      [24.1165237, 38.3409863],
#      [22.8905274, 38.3409863]]],
#    'type': 'Polygon'},
#   'contained_within': [],
#   'country': 'Ελλάς',
#   'country_code': 'GR',
#   'full_name': 'Αττική, Ελλάς',
#   'id': '00279a5763b04e35',
#   'name': 'Αττική',
#   'place_type': 'admin',
#   'url': 'https://api.twitter.com/1.1/geo/id/00279a5763b04e35.json'},
#  'possibly_sensitive': False,
#  'retweet_count': 1,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'Σεμηναριο επιχειρηματικοτητας! https://t.co/gV9q1nUzHF #mystylerocks #tsipras_proverbs #MeToo #thevoiceGR #shoppingstar #Flicker',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Fri Jul 30 15:57:40 +0000 2010',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'ανακάλυψε την επιχειρηματικότητα μεσα σου : https://t.co/LEPHbGFey1\n\nhttps://t.co/YCvPxY8zxh',
#   'entities': {'description': {'urls': [{'display_url': "olympicmarketingsystem.com/it'stimeincome…",
#       'expanded_url': "https://olympicmarketingsystem.com/it'stimeincomesal",
#       'indices': [44, 67],
#       'url': 'https://t.co/LEPHbGFey1'},
#      {'display_url': 'facebook.com/4urbusiness',
#       'expanded_url': 'http://facebook.com/4urbusiness',
#       'indices': [69, 92],
#       'url': 'https://t.co/YCvPxY8zxh'}]},
#    'url': {'urls': [{'display_url': "olympicmarketingsystem.com/it'stimeincome…",
#       'expanded_url': "https://olympicmarketingsystem.com/it'stimeincomesal",
#       'indices': [0, 23],
#       'url': 'https://t.co/LEPHbGFey1'}]}},
#   'favourites_count': 653,
#   'follow_request_sent': False,
#   'followers_count': 720,
#   'following': False,
#   'friends_count': 2019,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 172780518,
#   'id_str': '172780518',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'el',
#   'listed_count': 3,
#   'location': '',
#   'name': 'Γιωργος Σαλ',
#   'notifications': False,
#   'profile_background_color': '0099B9',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/432624640/vista_wow_wallpapers__3_.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/432624640/vista_wow_wallpapers__3_.jpg',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/172780518/1508516316',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/921410187004608513/f8wh2R-d_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/921410187004608513/f8wh2R-d_normal.jpg',
#   'profile_link_color': '0099B9',
#   'profile_sidebar_border_color': '5ED4DC',
#   'profile_sidebar_fill_color': '95E8EC',
#   'profile_text_color': '3C3940',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'GiorgosSal',
#   'statuses_count': 4285,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/LEPHbGFey1',
#   'utc_offset': None,
#   'verified': False}}

# %% [markdown]
# # Here we just extract the relevant data

# %%
#all_data[0]
for tweet in all_data:
        dictionary = {}
        screen_name = str(tweet['user']['name'])
        if screen_name:
            dictionary['screen_name'] = screen_name

        tweet_creation_date = str(tweet['created_at'])
        if tweet_creation_date:
            dictionary['tweet_creation_date'] = tweet_creation_date
        user_description = str(tweet['user']['description'])
        if user_description:
            dictionary['user_description'] = user_description
        tweet_text = str(tweet['text'])
        if tweet_text:
            dictionary['tweet_text'] = tweet_text
        followers_count = str(tweet['user']['followers_count'])
        if followers_count:
            dictionary['followers_count'] = followers_count
        coordinates = tweet['coordinates']
        if coordinates:
            dictionary['coordinates'] = coordinates
        account_creation_date = str(tweet['user']['created_at'])
        if account_creation_date:
            dictionary['account_creation_date'] = account_creation_date

        time_zone = str(tweet['user']['time_zone'])
        if time_zone:
            dictionary['time_zone'] = time_zone

        friends_count = str(tweet['user']['friends_count'])      
        if friends_count:
            dictionary['friends_count'] = friends_count

        user_id = str(tweet['user']['id'])
        if user_id:
            dictionary['user_id'] = user_id
        location = str(tweet['user']['location'])
        if location:
            dictionary['location'] = location
        total_retweets = str(tweet['retweet_count'])
        if total_retweets:
            dictionary['total_retweets'] = total_retweets

            our_list.append(dictionary)

print("done")
# Out:
# done

# %%
df = pd.DataFrame(our_list)

# %%
df.to_csv("greek_tweets.csv", index=False)

# %%
df.tail()
# Out:
#               account_creation_date followers_count friends_count  \
# 213  Mon Oct 16 10:59:12 +0000 2017              22            49
# 214  Tue May 05 11:03:40 +0000 2009            4737           354
# 215  Thu Sep 26 10:55:53 +0000 2013            6761           962
# 216  Wed Jul 01 14:02:33 +0000 2009           41947           453
# 217  Fri Apr 18 12:41:24 +0000 2008           17412         10046
#
#            location         screen_name time_zone total_retweets  \
# 213             NaN             kap.kap      None              0
# 214  Athens, Greece             in2life    Athens              0
# 215          Athens         Provocateur      None              0
# 216   Athens Greece    Eφημερίδα Η ΑΥΓΗ    Athens              0
# 217  Greece, Athens  Kostas Fryganiotis    Athens              1
#
#                 tweet_creation_date  \
# 213  Thu Oct 19 11:10:37 +0000 2017
# 214  Wed Oct 18 18:00:26 +0000 2017
# 215  Tue Oct 24 15:00:02 +0000 2017
# 216  Mon Nov 13 08:56:33 +0000 2017
# 217  Tue Oct 24 09:57:21 +0000 2017
#
#                                             tweet_text  \
# 213                    καμία ανοχή στο σεξισμό\n#MeToo
# 214  ΣΥΓΧΡΟΝΗ ΖΩΗ | #meToo: Το internet ενάντια στη...
# 215  Τι θα έγραφαν οι άντρες, σε ένα δικό τους #met...
# 216  Σουηδία: 456 γυναίκες ηθοποιοί καταγγέλλουν σε...
# 217                                -Καλημέρα\n- #MeToo
#
#                                       user_description             user_id
# 213      I'm feeling supersonic\nGive me gin and tonic  919880397521027072
# 214  Tips για το τι παίζει, πού και πότε, ιδέες για...            37901287
# 215              Ζωή και Εμπειρίες. Μυαλό και Σκέψεις.          1907507672
# 216          Η εφημερίδα της αριστεράς και στο twitter            52732962
# 217  Favstar: https://t.co/GdENLQfc2Y FB: https://t...            14432518

# %% [markdown]
# # The rest is just test data that I would have cleaned :)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime


# edit these three variables
user = 'metoo'
start = datetime.datetime(2017, 10, 20)  # year, month, day
end = datetime.datetime(2017, 11, 12)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()


# don't mess with this stuff
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item:not(.AdaptiveStreamUserGallery)'
user = user.lower()
ids = []


def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?l=fr&q='
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10

        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            increment += 10

           # found_tweets += next_tweets_chunk[:]

        print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))


        for tweet in found_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)

    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)


try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))
except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
#driver.close()
# Out:
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-20%20until%3A2017-10-21include%3Aretweets&src=typd
# 2017-10-20
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 140 tweets found, 0 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-21%20until%3A2017-10-22include%3Aretweets&src=typd
# 2017-10-21
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 475 tweets found, 140 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-22%20until%3A2017-10-23include%3Aretweets&src=typd
# 2017-10-22
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 349 tweets found, 615 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-23%20until%3A2017-10-24include%3Aretweets&src=typd
# 2017-10-23
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 363 tweets found, 964 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-24%20until%3A2017-10-25include%3Aretweets&src=typd
# 2017-10-24
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 361 tweets found, 1327 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-25%20until%3A2017-10-26include%3Aretweets&src=typd
# 2017-10-25
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 385 tweets found, 1688 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-26%20until%3A2017-10-27include%3Aretweets&src=typd
# 2017-10-26
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 317 tweets found, 2073 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-27%20until%3A2017-10-28include%3Aretweets&src=typd
# 2017-10-27
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 228 tweets found, 2390 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-28%20until%3A2017-10-29include%3Aretweets&src=typd
# 2017-10-28
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 177 tweets found, 2618 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-29%20until%3A2017-10-30include%3Aretweets&src=typd
# 2017-10-29
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 1255 tweets found, 2795 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-30%20until%3A2017-10-31include%3Aretweets&src=typd
# 2017-10-30
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 615 tweets found, 4050 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-10-31%20until%3A2017-11-01include%3Aretweets&src=typd
# 2017-10-31
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 311 tweets found, 4665 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-01%20until%3A2017-11-02include%3Aretweets&src=typd
# 2017-11-01
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 198 tweets found, 4976 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-02%20until%3A2017-11-03include%3Aretweets&src=typd
# 2017-11-02
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 155 tweets found, 5174 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-03%20until%3A2017-11-04include%3Aretweets&src=typd
# 2017-11-03
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 39 tweets found, 5329 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-04%20until%3A2017-11-05include%3Aretweets&src=typd
# 2017-11-04
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 39 tweets found, 5368 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-05%20until%3A2017-11-06include%3Aretweets&src=typd
# 2017-11-05
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 45 tweets found, 5407 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-06%20until%3A2017-11-07include%3Aretweets&src=typd
# 2017-11-06
# scrolling down to load more tweets
# scrolling down to load more tweets
# 24 tweets found, 5452 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-07%20until%3A2017-11-08include%3Aretweets&src=typd
# 2017-11-07
# scrolling down to load more tweets
# scrolling down to load more tweets
# 29 tweets found, 5476 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-08%20until%3A2017-11-09include%3Aretweets&src=typd
# 2017-11-08
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 31 tweets found, 5505 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-09%20until%3A2017-11-10include%3Aretweets&src=typd
# 2017-11-09
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 43 tweets found, 5536 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-10%20until%3A2017-11-11include%3Aretweets&src=typd
# 2017-11-10
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 30 tweets found, 5579 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-11%20until%3A2017-11-12include%3Aretweets&src=typd
# 2017-11-11
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# scrolling down to load more tweets
# 42 tweets found, 5609 total
# https://twitter.com/search?l=fr&q=metoo%20since%3A2017-11-12%20until%3A2017-11-13include%3Aretweets&src=typd
# 2017-11-12
# 6 tweets found, 5651 total
# tweets found on this scrape:  5657
# total tweet count:  5838
# all done here

# %%
with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

# %%
data_to_write[2919]
# Out:
# '921754371720990720'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-320-5cf7b8fe3097> in <module>()
#       5     else:
#       6         return (data_to_write[int(middle)], data_to_write[int(middle-1)])
# ----> 7 middle
#
# NameError: name 'middle' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from time import sleep
import json
import datetime


# edit these three variables
user = 'metoo'
start = datetime.datetime(2017, 10, 27)  # year, month, day
end = datetime.datetime(2017, 10, 28)  # year, month, day

# only edit these if you're having problems
delay = 1  # time to wait on each page load before reading the page
driver = webdriver.Chrome()  # options are Chrome() Firefox() Safari()


# don't mess with this stuff
twitter_ids_filename = 'all_ids.json'
days = (end - start).days + 1
id_selector = '.time a.tweet-timestamp'
tweet_selector = 'li.js-stream-item:not(.AdaptiveStreamUserGallery)'
user = user.lower()
ids = []


def format_day(date):
    day = '0' + str(date.day) if len(str(date.day)) == 1 else str(date.day)
    month = '0' + str(date.month) if len(str(date.month)) == 1 else str(date.month)
    year = str(date.year)
    return '-'.join([year, month, day])

def form_url(since, until):
    p1 = 'https://twitter.com/search?l=fr&q='
    p2 =  user + '%20since%3A' + since + '%20until%3A' + until + 'include%3Aretweets&src=typd'
    return p1 + p2

def increment_day(date, i):
    return date + datetime.timedelta(days=i)

for day in range(days):
    d1 = format_day(increment_day(start, 0))
    d2 = format_day(increment_day(start, 1))
    url = form_url(d1, d2)
    print(url)
    print(d1)
    driver.get(url)
    sleep(delay)

    try:
        found_tweets = driver.find_elements_by_css_selector(tweet_selector)
        increment = 10
        while len(found_tweets) >= increment:
            print('scrolling down to load more tweets')
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            time.sleep(delay)
            found_tweets = driver.find_elements_by_css_selector(tweet_selector)
            all_tweets += found_tweets[:]

            print('{} tweets found, {} total'.format(len(found_tweets), len(ids)))
            increment += 10


        for tweet in all_tweets:
            try:
                id = tweet.find_element_by_css_selector(id_selector).get_attribute('href').split('/')[-1]
                ids.append(id)
            except StaleElementReferenceException as e:
                print('lost element reference', tweet)



    except NoSuchElementException:
        print('no tweets on this day')

    start = increment_day(start, 1)


try:
    with open(twitter_ids_filename) as f:
        all_ids = ids + json.load(f)
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))
except FileNotFoundError:
    with open(twitter_ids_filename, 'w') as f:
        all_ids = ids
        data_to_write = list(set(all_ids))
        print('tweets found on this scrape: ', len(ids))
        print('total tweet count: ', len(data_to_write))

with open(twitter_ids_filename, 'w') as outfile:
    json.dump(data_to_write, outfile)

print('all done here')
#driver.close()

# %%
import tweepy
import json
import math
import glob
import csv
import zipfile
import zlib
from tweepy import TweepError
from time import sleep

# CHANGE THIS TO THE USER YOU WANT
user = 'metoo'

with open('api_keys.json') as f:
    keys = json.load(f)

auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
auth.secure = True
api = tweepy.API(auth)

user = user.lower()
output_file = '{}.json'.format(user)
output_file_short = '{}_short.json'.format(user)
compression = zipfile.ZIP_DEFLATED

with open('all_ids.json') as f:
    ids = json.load(f)

print('total ids: {}'.format(len(ids)))

all_data = []
start = 0
end = 100
limit = len(ids)
i = math.ceil(limit / 100)

for go in range(i):
    print('currently getting {} - {}'.format(start, end))
    sleep(6)  # needed to prevent hitting API rate limit
    id_batch = ids[start:end]
    start += 100
    end += 100
    tweets = api.statuses_lookup(id_batch)
    for tweet in tweets:
        all_data.append(dict(tweet._json))

print('metadata collection complete')
print('creating master json file')
with open(output_file, 'w') as outfile:
    json.dump(all_data, outfile)

print('creating ziped master json file')
zf = zipfile.ZipFile('{}.zip'.format(user), mode='w')
zf.write(output_file, compress_type=compression)
zf.close()

results = []

def is_retweet(entry):
    return 'retweeted_status' in entry.keys()

def get_source(entry):
    if '<' in entry["source"]:
        return entry["source"].split('>')[1].split('<')[0]
    else:
        return entry["source"]

with open(output_file) as json_data:
    data = json.load(json_data)
    for entry in data:
        t = {
            "created_at": entry["created_at"],
            "text": entry["text"],
            "in_reply_to_screen_name": entry["in_reply_to_screen_name"],
            "retweet_count": entry["retweet_count"],
            "favorite_count": entry["favorite_count"],
            "source": get_source(entry),
            "id_str": entry["id_str"],
            "is_retweet": is_retweet(entry)
        }
        results.append(t)

# print('creating minimized json master file')
# with open(output_file_short, 'w') as outfile:
#     json.dump(results, outfile)

with open(output_file_short) as master_file:
    data = json.load(master_file)
    fields = ["favorite_count", "source", "text", "in_reply_to_screen_name", "is_retweet", "created_at", "retweet_count", "id_str"]
    print('creating CSV version of minimized json master file')
    f = csv.writer(open('{}.csv'.format(user), 'w'))
    f.writerow(fields)
    for x in data:
        f.writerow([x["favorite_count"], x["source"], x["text"], x["in_reply_to_screen_name"], x["is_retweet"], x["created_at"], x["retweet_count"], x["id_str"]])
# Out:
# total ids: 2920
# currently getting 0 - 100
# currently getting 100 - 200
# currently getting 200 - 300
# currently getting 300 - 400
# currently getting 400 - 500
# currently getting 500 - 600
# currently getting 600 - 700
# currently getting 700 - 800
# currently getting 800 - 900
# currently getting 900 - 1000
# currently getting 1000 - 1100
# currently getting 1100 - 1200
# currently getting 1200 - 1300
# currently getting 1300 - 1400
# currently getting 1400 - 1500
# currently getting 1500 - 1600
# currently getting 1600 - 1700
# currently getting 1700 - 1800
# currently getting 1800 - 1900
# currently getting 1900 - 2000
# currently getting 2000 - 2100
# currently getting 2100 - 2200
# currently getting 2200 - 2300
# currently getting 2300 - 2400
# currently getting 2400 - 2500
# currently getting 2500 - 2600
# currently getting 2600 - 2700
# currently getting 2700 - 2800
# currently getting 2800 - 2900
# currently getting 2900 - 3000
# metadata collection complete
# creating master json file
# creating ziped master json file
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-332-351ecd7774a1> in <module>()
#      86 #     json.dump(results, outfile)
#      87
# ---> 88 with open(output_file_short) as master_file:
#      89     data = json.load(master_file)
#      90     fields = ["favorite_count", "source", "text", "in_reply_to_screen_name", "is_retweet", "created_at", "retweet_count", "id_str"]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'metoo_short.json'
