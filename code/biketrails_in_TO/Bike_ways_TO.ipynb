# %%
import pandas as pd

import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %%
df_bikeways = gpd.read_file("bikeways_wgs84/CENTRELINE_BIKEWAY_OD_WGS84.shp")

# %%
df_bikeways
# Out:
#        ADDRESS_L ADDRESS_R                     CP_TYPE           DIR_CODE_D  \
# 0                              Major Multi-use Pathway          Not One-Way
# 1                                                               Not One-Way
# 2                              Major Multi-use Pathway          Not One-Way
# 3                                                               Not One-Way
# 4                              Major Multi-use Pathway          Not One-Way
# 5                                                               Not One-Way
# 6                              Major Multi-use Pathway          Not One-Way
# 7          25-25      8-30                                      Not One-Way
# 8      3795-3815                                                Not One-Way
# 9                   89-107                                      Not One-Way
# 10                             Major Multi-use Pathway          Not One-Way
# ...
